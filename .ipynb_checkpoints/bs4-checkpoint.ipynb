# %%
# json - 서버를 호출해서 값을 받아옴
import requests

url = "http://ihongss.com/xml/exam1.xml"
response = requests.get(url)
response.text # str

# %%
# xml - 서버를 호출해서 값을 받아옴
import urllib.request

url = "http://ihongss.com/xml/exam1.xml"
response = urllib.request.urlopen(url)
response.read() # bytes

# %%
! pip install beautifulsoup4

# %%
import requests
import bs4

url = "http://ihongss.com/xml/exam1.xml"
response = requests.get(url)
response.text

# xml일 경우 lxml-xml ,html일 경우 html.parser
soup = bs4.BeautifulSoup(response.text,'lxml-xml')
soup

# soup.find_all() : 여러개 검색 (list)
# soup.find() : 가장 먼저 검색 되는 것 1개
# soup.select('div.abc') : 여러개 검색 (list) class .abc를 검색. #abc => id abc를 검색
# soup.select_one() : 가장 먼저 검색 되는 것 1개
print(soup)
print('=' * 30)

for tmp in soup.find_all('item'):
    print(tmp)
    # name = tag이름 , attrs = 속성, text = 태그사의 내용
    print(tmp.name, tmp.attrs['id'],tmp.find('name').text) # tag(문자) , attrs(dict) 
    print("-" * 30)

# %%
import requests
import bs4

url = "http://ihongss.com/resources/student.xml"
response = requests.get(url)
response.text

# xml일 경우 lxml-xml ,html일 경우 html.parser
soup = bs4.BeautifulSoup(response.text,'lxml-xml')
soup

# a 11 id_a addr1
# b 22 id_b addr2
print(soup)
print('=' * 30)
for tmp in soup.find_all('student'):
    print(tmp.find('name').text,
          tmp.find('age').text,
          tmp.find('addr').attrs['id'],
          tmp.find('addr').text)

# %%
import requests
import bs4

url = "http://ihongss.com/resources/exam1.html"
response = requests.get(url)
response.text

# xml일 경우 lxml-xml ,html일 경우 html.parser
soup = bs4.BeautifulSoup(response.text,'html.parser')
a = soup.find('div') # 첫번째 tag만 출력
a

b = soup.find_all('div') # div 전체
b

# div 태그중에서 class = 'first'
c = soup.find_all('div',{'class':'first'})
c

# 전체 div를 반복
for tmp in b:
    print('=' * 30)
    for tmp1 in tmp.find_all('p'):
        # attrs 가 있는 값과 없는 값을 구별 할 때 get을 이용하여 구분하여 데이터를 추출한다.
        
        print(tmp1.text,tmp1.attrs.get('id',""))
        # if문을 통해서도 구별 가능
        if not tmp1.attrs.get('id'):
            print('empty')

# %%
import requests
import bs4

url = "https://www.boannews.com/Default.asp"
response = requests.get(url)

# xml일 경우 lxml-xml ,html일 경우 html.parser
soup = bs4.BeautifulSoup(response.text,'html.parser')
soup

soup.find('body')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko" xml:lang="ko" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <title>보안뉴스</title>
# <link href="https://www.boannews.com/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <meta content="http://www.boannews.com/images/top/boannews_icon2.png" itemprop="image"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="http://www.boannews.com" rel="canonical"/>
# <meta content="국내 최대 보안 언론/커뮤니티-보안뉴스" name="description"/>
# <meta content="website" property="og:type"/>
# <meta content="보안뉴스" property="og:title"/>
# <meta content="국내 최대 보안 언론/커뮤니티-보안뉴스" property="og:description"/>
# <meta content="http://www.boannews.com/images/top/boannews_ci.png" property="og:image"/>
# <meta content="www.boannews.com" property="og:url"/>
# <meta content="5bLNClj6UIZeIR58-jooPOBw2eKomfQJXIyOmVbv0pk" name="google-site-verification">
# <link href="http://www.boannews.com/images/top/boannews_ci.png" rel="image_src">
# <link href="css/main_style.css?version=2.5" rel="stylesheet" type="text/css"/>
# <script src="/js/jquery-1.12.4.min.js" type="text/javascript"></script>
# <script src="/js/slides.js" type="text/javascript"></script>
# <script src="js/osAjaxSample.js" type="text/javascript"></script>
# <script src="include/chkForm.js" type="text/javascript"></script>
# <script type="text/javascript">
# //쿠키설정     레이어팝업
# function setCookie( name, value, expiredays ) {
# 	var todayDate = new Date();
# //	todayDate.setDate( todayDate.getDate() + expiredays ); //24시간
# 	todayDate.setTime(todayDate.getTime() + (60*60*1000*12)); //12시간
# 	document.cookie = name + "=" + escape( value ) + "; path=/; expires=" + todayDate.toGMTString() + ";"
# }
#
# //쿠키가져오기
# function getCookie( name ) {
# 	var nameOfCookie = name + "=";
# 	var x = 0;
# 	while ( x <= document.cookie.length ){
# 	var y = (x+nameOfCookie.length);
# 	if ( document.cookie.substring( x, y ) == nameOfCookie ) {
# 		if ( (endOfCookie=document.cookie.indexOf( ";", y )) == -1 )
# 			endOfCookie = document.cookie.length;
# 			return unescape( document.cookie.substring( y, endOfCookie ) );
# 		}
# 		x = document.cookie.indexOf( " ", x ) + 1;
# 		if ( x == 0 )
# 		break;
# 	}
# 	return "";
# }
#
# //쿠키 설정여부체크
# //$(function(){
# //	if ( getCookie( "event_pop") != "done" ) {
# //		document.getElementById("div_popup").style.display ="block";
# //	}else{
# //document.getElementById("div_popup").style.display ="none";
# //	}
# //});
#
# //윈도우창을 닫음
# function closeWin() {
# 	if ( document.notice_form.chkbox.checked ){
# 		setCookie( "event_pop", "done" , 1 );
# 	}
# 	document.getElementById("div_popup").style.display ="none";
# }
#
#
#
# //function radio_ad(){
# //	var radio= document.getElementById("radio");
# //	if (radio.paused) {
# //		radio.play();
# //	}else{
# //		radio.pause();
# //		radio.currentTime = 0;
# //	}
# //}
#
# //window.onload= function(){
# //	if (getCookie("radio_ad") != "done") {
# //		radio_ad();
# //		setCookie("radio_ad", "done" , 1 );
# //	}
# //}
# </script>
# </link></meta></head>
# <body>
# <!--
# <audio id="radio">
# <source src="/images/cm.mp3" type="audio/mp3">
# </audio>
# -->
# <!--Include virtual="/secu_admin/ad_log/log.asp"-->
# <link href="http://www.boannews.com/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <script src="/JS/activex_load.js" type="text/javascript"></script>
# <script type="text/javascript">
# function MM_swapImgRestore() { //v3.0
#   var i,x,a=document.MM_sr; for(i=0;a&&i<a.length&&(x=a[i])&&x.oSrc;i++) x.src=x.oSrc;
# }
#
# function MM_preloadImages() { //v3.0
#   var d=document; if(d.images){ if(!d.MM_p) d.MM_p=new Array();
#     var i,j=d.MM_p.length,a=MM_preloadImages.arguments; for(i=0; i<a.length; i++)
#     if (a[i].indexOf("#")!=0){ d.MM_p[j]=new Image; d.MM_p[j++].src=a[i];}}
# }
#
# function MM_findObj(n, d) { //v4.01
#   var p,i,x;  if(!d) d=document; if((p=n.indexOf("?"))>0&&parent.frames.length) {
#     d=parent.frames[n.substring(p+1)].document; n=n.substring(0,p);}
#   if(!(x=d[n])&&d.all) x=d.all[n]; for (i=0;!x&&i<d.forms.length;i++) x=d.forms[i][n];
#   for(i=0;!x&&d.layers&&i<d.layers.length;i++) x=MM_findObj(n,d.layers[i].document);
#   if(!x && d.getElementById) x=d.getElementById(n); return x;
# }
#
# function MM_swapImage() { //v3.0
#   var i,j=0,x,a=MM_swapImage.arguments; document.MM_sr=new Array; for(i=0;i<(a.length-2);i+=3)
#    if ((x=MM_findObj(a[i]))!=null){document.MM_sr[j++]=x; if(!x.oSrc) x.oSrc=x.src; x.src=a[i+2];}
# }
#
# function searchForm(){
# 	if(!document.form_search.find.value){
# 		alert("검색어를 입력하세요!");
# 		document.form_search.find.focus();
# 		return false;
# 	}
# 	document.form_search.q.value=document.form_search.find.value;
# 	return true;
# }
#
# function inputCheckTopSearch(f){
# 	re = /[~!@\#$%^&*\()\-=+_"><:|']/gi;
# 	if(re.test(f.find.value)){
# 		alert("특수문자는 입력하실 수 없습니다.");
# 		f.find.value=f.find.value.replace(re,"");
# 		f.find.focus();
# 	}
# }
#
# function add_favorites(){
# 	var favorite_url = "http://www.boannews.com"   //즐겨찾기에 추가할 홈 주소
# 	var favorite_title = "안전한 세상을 위한 뉴스 -보안뉴스"   // 즐겨찾기에 기록할 이름(제목)을 기록
# 	if (document.all){
# 		window.external.AddFavorite(favorite_url,favorite_title)
# 	}
# }
#
#
# // 구글 로그분석 Start
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-9071708-4']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
# // 구글 로그분석 end
#
# function main_menu_view(){
# 	main_menu_hide.style.display="block";
# }
# </script>
# <style type="text/css">
# #top_slide_ad { width:100%; height:180px; background:#003F89 url('/images/top/top_banner_bg.png') no-repeat center;}
# #top_slide_area{width:1125px; height:100px; margin:0 auto; padding:8px 0 0 30px;}
# .top_banner_title{margin:0; padding:0; font-family:'Noto Sans KR'; font-size:30px; color:#FFFFFF; font-weight:700; line-height:65px; text-align:left;}
# .top_banner_close{float:right; cursor:pointer;}
# .top_banner_wraper {position: absolute; width: 1100px; height: 80px; margin:0 auto; background-color:#FFFFFF; overflow: hidden; }
# .top_banner_wraper img {position: absolute; margin: 10px 0 0 0;}
# </style>
# <script type="text/javascript">
# $(document).ready(function() {
# 	var bannerLeft=0;
# 	var first=1;
# 	var last;
# 	var imgCnt=0;
# 	var $img = $(".top_banner_wraper img");
# 	var $first;
# 	var $last;
#
# 	$img.each(function(){  //32px 간격으로 배너 처음 위치 시킴
# 		$(this).css("left",bannerLeft);
# 		bannerLeft += $(this).width()+12;
# 		$(this).attr("id", "banner"+(++imgCnt));  // img에 id 속성 추가
# 	});
#
# 	if( imgCnt > 7){  //배너 6개 이상이면 이동시킴
# 		last = imgCnt;
# 		setInterval(function() {
# 			$img.each(function(){
# 				$(this).css("left", $(this).position().left-1);  // 1px씩 왼쪽으로 이동
# 			});
# 			$first = $("#banner"+first);
# 			$last = $("#banner"+last);
# 			if($first.position().left < -150) {  // 제일 앞에 배너 제일 뒤로 옮김
# 				$first.css("left", $last.position().left + $last.width()+12 );
# 				first++;
# 				last++;
# 				if(last > imgCnt) { last=1; }
# 				if(first > imgCnt) { first=1; }
# 			}
# 		}, 10);   //속도 조정
# 	}
# });
#
# function top_banner_close() {
# 	$("#top_slide_ad").animate({height:0}, 300);
# 	$(".top_banner_wraper").animate({height:0}, 200);
# 	$(".top_banner_title").hide();
# 	$(".top_banner_close").hide();
#
# 	$('#scroll_banner1').animate({top:'-=180'}, 300);
# 	$('#scroll_banner2').animate({top:'-=180'}, 300);
# }
# </script>
# <div id="top_slide_ad">
# <div id="top_slide_area">
# <p class="top_banner_title">보안뉴스 창간 15주년을 축하합니다!!</p>
# <div class="top_banner_wraper">
# <a href="/custom/banner_page.asp?idx=817" onfocus="this.blur();" target="_blank"><img alt="" height="60" src="/images/banner/2.jpg" width="147"/></a><a href="/custom/banner_page.asp?idx=816" onfocus="this.blur();" target="_blank"><img alt="" height="60" src="/images/banner/3.jpg" width="147"/></a><a href="/custom/banner_page.asp?idx=815" onfocus="this.blur();" target="_blank"><img alt="" height="60" src="/images/banner/4(0).jpg" width="147"/></a><a href="/custom/banner_page.asp?idx=814" onfocus="this.blur();" target="_blank"><img alt="" height="60" src="/images/banner/5.jpg" width="147"/></a><a href="/custom/banner_page.asp?idx=813" onfocus="this.blur();" target="_blank"><img alt="" height="60" src="/images/banner/6(0).jpg" width="147"/></a><a href="/custom/banner_page.asp?idx=811" onfocus="this.blur();" target="_blank"><img alt="" height="60" src="/images/banner/8(0).jpg" width="147"/></a><a href="/custom/banner_page.asp?idx=810" onfocus="this.blur();" target="_blank"><img alt="" height="60" src="/images/banner/9.jpg" width="147"/></a><a href="/custom/banner_page.asp?idx=809" onfocus="this.blur();" target="_blank"><img alt="" height="60" src="/images/banner/10(0).jpg" width="147"/></a><a href="/custom/banner_page.asp?idx=808" onfocus="this.blur();" target="_blank"><img alt="" height="60" src="/images/banner/11.jpg" width="147"/></a><a href="/custom/banner_page.asp?idx=807" onfocus="this.blur();" target="_blank"><img alt="" height="60" src="/images/banner/12.jpg" width="147"/></a><a href="/custom/banner_page.asp?idx=806" onfocus="this.blur();" target="_blank"><img alt="" height="60" src="/images/banner/13.jpg" width="147"/></a><a href="/custom/banner_page.asp?idx=812" onfocus="this.blur();" target="_blank"><img alt="" height="60" src="/images/banner/7.jpg" width="147"/></a><a href="/custom/banner_page.asp?idx=819" onfocus="this.blur();" target="_blank"><img alt="" height="60" src="/images/banner/1.jpg" width="147"/></a><a href="/custom/banner_page.asp?idx=820" onfocus="this.blur();" target="_blank"><img alt="" height="60" src="/images/banner/14.jpg" width="147"/></a><a href="/custom/banner_page.asp?idx=821" onfocus="this.blur();" target="_blank"><img alt="" height="60" src="/images/banner/3(0).jpg" width="147"/></a><a href="/custom/banner_page.asp?idx=822" onfocus="this.blur();" target="_blank"><img alt="" height="60" src="/images/banner/nexon(0).jpg" width="147"/></a>
# </div>
# <!--img src="/images/btn/close.gif" class="top_banner_close" onclick="top_banner_close();"-->
# </div>
# </div>
# <!--
# <div id="top_moveIcon">
# 	<div style="font-size:11px; float:left; padding-left:20px;">
# 		<img src="/images/family/tm14.gif"border="0">
# 		<img src="/images/family/tm13.gif"border="0">&nbsp;&nbsp;
# 		<A HREF="http://www.boannews.com" target="_blank" onfocus="this.blur();"><img src="/images/family/tm00.gif" border="0"></A>&nbsp;&nbsp;
# 		<A HREF="http://www.industrynews.co.kr/" target="_blank" onfocus="this.blur();" ><img src="/images/family/tm19.gif" border="0"></A>&nbsp;&nbsp;
# 		<A HREF="/securityworld/default.asp" target="_blank" onfocus="this.blur();" ><img src="/images/family/tm02.gif" border="0"></A>&nbsp;&nbsp;
# 		<A HREF="http://www.solartodaymag.com" target="_blank" onfocus="this.blur();"><img src="/images/family/tm05.gif" border="0"></A>&nbsp;&nbsp;
# 		<A HREF="http://www.fajournal.com" target="_blank" onfocus="this.blur();"><img src="/images/family/tm07.gif" border="0"></A>&nbsp;&nbsp;
# 		<img src="/images/arrow_white.gif" width="110" height="1" alt="" />
# 	</div>
# 	<div style="font-size:11px; float:right; padding-right:20px;">
# 		<A HREF="http://www.seconexpo.com/" target="_blank" onfocus="this.blur();"><img src="/images/family/tm10.gif" border="0" alt="세계 보안 엑스포"></A>
# 		&nbsp;<A HREF="http://www.egisec.org" target="_blank" onfocus="this.blur();"><img src="/images/family/tm17.gif" border="0" alt="전자정부 솔루션 페어"></A>
# 		&nbsp;<A HREF="http://www.pisfair.org" target="_blank" onfocus="this.blur();"><img src="/images/family/tm09.gif" border="0" alt="개인정보보호 페어"></A>
# 		&nbsp;<A HREF="http://www.isecconference.org" target="_blank" onfocus="this.blur();"><img src="/images/family/tm08.gif" border="0" alt="국제 사이버 시큐리티 컨퍼런스"></A>
# 		&nbsp;<A HREF="http://www.exposolar.org" target="_blank" onfocus="this.blur();"><img src="/images/family/tm12.gif" border="0" alt="세계 태양에너지 엑스포"></A>
# 		&nbsp;<A HREF="http://www.smartfactorykorea.com" target="_blank" onfocus="this.blur();"><img src="/images/family/tm18.gif" border="0" alt="스마트팩토리"></A>
# 		&nbsp;<A HREF="http://www.info-con.org" target="_blank" onfocus="this.blur();"><img src="/images/family/tm16.gif" border="0" alt="INFO-CON"></A>
# 	</div>
# </div>
# -->
# <div id="top_wrap">
# <div id="header">
# <div id="top_category" style="margin-top:5px;">
# <div id="top_banner"><a href="/securityworld/"><img src="/securityworld/img/sw.png" style="margin-top:25px;" width="180"/></a>
# <!--<IFRAME NAME="main_top" id="main_top" width="250" height="65" SRC="/main_files/top_banner.asp" frameborder="0"></IFRAME>--></div>
# <div id="top_logo"><a href="/default.asp" onfocus="this.blur();"><img alt="" height="65" src="/pds/main/default_ci.gif" width="340"/></a></div>
# <div id="search">
# <div id="AddMenu">
# <ul>
# <li>
# <a href="/custom/member_login.asp">로그인</a>
# <span style="">|</span>
# </li>
# <li>
# <a href="/custom/member_join.asp">회원가입</a>
# <span style="">|</span>
# </li>
# <li>
# <a href="/custom/news_jebo.asp">기사제보</a>
# <span style="">|</span>
# </li>
# <li>
# <a href="/custom/scrap_list.asp">스크랩</a>
# 			</li>
# </ul>
# </div>
# <div id="searchbox">
# <div class="social">
# <a href="https://www.facebook.com/boannews" onfocus="this.blur();" target="_blank"><img src="/images/new02/social1.gif"/></a>
# <a href="https://twitter.com/boannews" onfocus="this.blur();" target="_blank"><img src="/images/new02/social2.gif"/></a>
# <a href="https://post.naver.com/boannews6931" onfocus="this.blur();" target="_blank"><img src="/images/new02/social3.gif"/></a>
# <a href="https://pf.kakao.com/_nLKAxd" onfocus="this.blur();" target="_blank"><img src="/images/new02/social4.gif"/></a>
# <img src="/images/new02/social5.gif"/>
# </div>
# <form action="/search/list.asp" id="cse-search-box" method="get" name="form_search" onsubmit="return searchForm()">
# <input name="cx" type="hidden" value="partner-pub-9930086282638035:g8e0u1-r8xa"/>
# <input name="cof" type="hidden" value="FORID:9"/>
# <input name="ie" type="hidden" value="EUC-KR"/>
# <input name="q" size="12" type="hidden"/>
# <input name="sa" type="hidden" value="검색"/>
# <div class="find01">
# <select name="search" size="1" style="height:23px;font-size:13px;border:1px solid #d5d5d5;">
# <option value="">통합검색</option>
# <option value="key_word">뉴스</option>
# <option value="writer">기자명</option>
# <option value="content">컨텐츠</option>
# <option value="c_company">상호검색</option>
# <option value="c_product">제품검색</option>
# </select>
# </div>
# <input class="find" maxlength="20" name="find" onkeyup="inputCheckTopSearch(document.form_search);" type="text"/>
# <div class="find03"><input alt="검색" src="/images/new02/search.gif" type="image"/></div>
# </form>
# </div>
# </div>
# </div>
# <div class="top_line"></div>
# <div id="MainMenu_area">
# <ul id="main_menu_hide" onmouseout="this.style.display='none';" onmouseover="this.style.display='block';">
# <li class="menu" onclick="location.href='/media/t_list.asp?mkind=0';" onfocus="this.blur();">전체기사</li>
# <li class="menu" onclick="location.href='/media/list.asp?mkind=1';" onfocus="this.blur();">SECURITY</li>
# <li class="menu" onclick="location.href='/media/list.asp?mkind=2';" onfocus="this.blur();">IT</li>
# <li class="menu" onclick="location.href='/media/list.asp?mkind=4';" onfocus="this.blur();">SAFETY</li>
# <li class="menu2" onclick="location.href='/securityworld/';" onfocus="this.blur();"><i>Security World</i></li>
# </ul>
# <div id="main_menu_hash">
# <a href="javascript:main_menu_view();"><img src="/images/new02/all_menu_btn.png"/></a>
# <a href="/media/t_list.asp">#전체기사</a>
# <a href="https://www.boannews.com/securityworld/">#시큐리티월드</a>
# <!--<a href="/search/news_list.asp?search=key_word&find=">#</a>-->
# <a href="https://www.boannews.com/search/news_total.asp?search=key_word&amp;find=%BB%E7%B0%C7%BB%E7%B0%ED">#사건사고</a>
# <!--<a href="/search/news_list.asp?search=key_word&find=">#</a>-->
# <a href="https://www.boannews.com/search/news_total.asp?search=title&amp;find=스마트폰보안">#스마트폰보안</a>
# <!--<a href="/search/news_list.asp?search=key_word&find=">#</a>-->
# <a href="https://www.boannews.com/search/news_total.asp?search=title&amp;find=다크웹">#다크웹</a>
# <!--<a href="/search/news_list.asp?search=key_word&find=">#</a>-->
# <a href="https://www.boannews.com/search/news_total.asp?search=title&amp;find=세계보안엑스포">#세계보안엑스포</a>
# <!--<a href="/search/news_list.asp?search=key_word&find=">#</a>-->
# </div>
# <div id="AddMenu2">
# <ul>
# <!--
#
# 					<li><a href="/securityworld/"><img src="/securityworld/img/sw.png" height="17" style="margin:5px 20px 0 0;"></a></li>
#
# 			<li>
# 				<img src="/images/new/icon1.gif" style="margin:0;padding:0;vertical-align:middle;">
# 				<a href="/media/s_list.asp?skind=C" style="font-size:15px;color:#359BED;font-weight:400">동영상</a>
# 			</li>
# 			<li>
# 				<img src="/images/new/icon2.gif" style="margin:0;padding:0;vertical-align:middle;margin-left:20px;">
# 				<a href="/media/s_list.asp?skind=J" style="font-size:15px;color:#359BED;font-weight:400">카드뉴스</a>
# 			</li>
# 			-->
# <li>
# <img src="/images/new/icon4.gif" style="margin:0;padding:0;vertical-align:middle;margin-left:20px;"/>
# <a href="/newsletter/" style="font-size:15px;color:#359BED;font-weight:400">뉴스레터 신청</a>
# </li>
# <li>
# <img src="/images/new/icon3.gif" style="margin:0;padding:0;vertical-align:middle;margin-left:20px;"/>
# <a href="/security_contents/info/list.asp" style="font-size:15px;color:#359BED;font-weight:400">시큐리티 콘텐츠</a>
# 			</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div id="wrap">
# <div id="body">
# <div id="headline_area">
# <div id="headline0">
# <div class="headline_big_img" onclick="location.href='/media/view.asp?idx=97673';" style="background: #fff url(/media/upFiles2/2021/05/823969336_1150.jpg) center center no-repeat;background-size:cover;"><p class="gradient"><a href="/media/view.asp?idx=97673">[황민주 보안에세이] 시간의 숙성과 지능형 지속공격...</a></p></div>
# <ul class="headline_small_img">
# <li name="headline_img1" onclick="location.href='/media/view.asp?idx=97673';" onmouseout="start(1);" onmouseover="headline_news(1);"><p>[황민주 보안에세이] 시간의 숙성과 지능형 지속공격의 관계</p></li>
# <li name="headline_img2" onclick="location.href='/media/view.asp?idx=97635';" onmouseout="start(2);" onmouseover="headline_news(2);"><p>[보.알.남] 나쁜 인공지능 만들기, 데이터 포이즈닝</p></li>
# <li name="headline_img3" onclick="location.href='/media/view.asp?idx=97638';" onmouseout="start(3);" onmouseover="headline_news(3);"><p>[한국정보보호학회 칼럼] 융합산업과 IoBE(Internet of Blend...</p></li>
# <li name="headline_img4" onclick="location.href='/media/view.asp?idx=97637';" onmouseout="start(4);" onmouseover="headline_news(4);"><p>MS 익스체인지에서 제로데이 발표되자 5분 만에 스캔 시작한 해커들</p></li>
# <li name="headline_img5" onclick="location.href='/media/view.asp?idx=97634';" onmouseout="start(5);" onmouseover="headline_news(5);"><p>RSA 컨퍼런스에서 발표한 솔라윈즈 CEO, “보안은 공동의 책임”</p></li>
# </ul>
# </div>
# <div id="headline1">
# <div class="headline_big_img" onclick="location.href='/media/view.asp?idx=97635';" style="background: #fff url(/media/upFiles2/2021/05/610445067_5688.jpg) center center no-repeat;background-size:cover;"><p class="gradient"><a href="/media/view.asp?idx=97635">[보.알.남] 나쁜 인공지능 만들기, 데이터 포이즈...</a></p></div>
# <ul class="headline_small_img">
# <li name="headline_img1" onclick="location.href='/media/view.asp?idx=97673';" onmouseout="start(1);" onmouseover="headline_news(1);"><p>[황민주 보안에세이] 시간의 숙성과 지능형 지속공격의 관계</p></li>
# <li name="headline_img2" onclick="location.href='/media/view.asp?idx=97635';" onmouseout="start(2);" onmouseover="headline_news(2);"><p>[보.알.남] 나쁜 인공지능 만들기, 데이터 포이즈닝</p></li>
# <li name="headline_img3" onclick="location.href='/media/view.asp?idx=97638';" onmouseout="start(3);" onmouseover="headline_news(3);"><p>[한국정보보호학회 칼럼] 융합산업과 IoBE(Internet of Blend...</p></li>
# <li name="headline_img4" onclick="location.href='/media/view.asp?idx=97637';" onmouseout="start(4);" onmouseover="headline_news(4);"><p>MS 익스체인지에서 제로데이 발표되자 5분 만에 스캔 시작한 해커들</p></li>
# <li name="headline_img5" onclick="location.href='/media/view.asp?idx=97634';" onmouseout="start(5);" onmouseover="headline_news(5);"><p>RSA 컨퍼런스에서 발표한 솔라윈즈 CEO, “보안은 공동의 책임”</p></li>
# </ul>
# </div>
# <div id="headline2">
# <div class="headline_big_img" onclick="location.href='/media/view.asp?idx=97638';" style="background: #fff url(/media/upFiles2/2021/05/610445067_3291.jpg) center center no-repeat;background-size:cover;"><p class="gradient"><a href="/media/view.asp?idx=97638">[한국정보보호학회 칼럼] 융합산업과 IoBE(Int...</a></p></div>
# <ul class="headline_small_img">
# <li name="headline_img1" onclick="location.href='/media/view.asp?idx=97673';" onmouseout="start(1);" onmouseover="headline_news(1);"><p>[황민주 보안에세이] 시간의 숙성과 지능형 지속공격의 관계</p></li>
# <li name="headline_img2" onclick="location.href='/media/view.asp?idx=97635';" onmouseout="start(2);" onmouseover="headline_news(2);"><p>[보.알.남] 나쁜 인공지능 만들기, 데이터 포이즈닝</p></li>
# <li name="headline_img3" onclick="location.href='/media/view.asp?idx=97638';" onmouseout="start(3);" onmouseover="headline_news(3);"><p>[한국정보보호학회 칼럼] 융합산업과 IoBE(Internet of Blend...</p></li>
# <li name="headline_img4" onclick="location.href='/media/view.asp?idx=97637';" onmouseout="start(4);" onmouseover="headline_news(4);"><p>MS 익스체인지에서 제로데이 발표되자 5분 만에 스캔 시작한 해커들</p></li>
# <li name="headline_img5" onclick="location.href='/media/view.asp?idx=97634';" onmouseout="start(5);" onmouseover="headline_news(5);"><p>RSA 컨퍼런스에서 발표한 솔라윈즈 CEO, “보안은 공동의 책임”</p></li>
# </ul>
# </div>
# <div id="headline3">
# <div class="headline_big_img" onclick="location.href='/media/view.asp?idx=97637';" style="background: #fff url(/media/upFiles2/2021/05/610494698_1561.jpg) center center no-repeat;background-size:cover;"><p class="gradient"><a href="/media/view.asp?idx=97637">MS 익스체인지에서 제로데이 발표되자 5분 만에 스...</a></p></div>
# <ul class="headline_small_img">
# <li name="headline_img1" onclick="location.href='/media/view.asp?idx=97673';" onmouseout="start(1);" onmouseover="headline_news(1);"><p>[황민주 보안에세이] 시간의 숙성과 지능형 지속공격의 관계</p></li>
# <li name="headline_img2" onclick="location.href='/media/view.asp?idx=97635';" onmouseout="start(2);" onmouseover="headline_news(2);"><p>[보.알.남] 나쁜 인공지능 만들기, 데이터 포이즈닝</p></li>
# <li name="headline_img3" onclick="location.href='/media/view.asp?idx=97638';" onmouseout="start(3);" onmouseover="headline_news(3);"><p>[한국정보보호학회 칼럼] 융합산업과 IoBE(Internet of Blend...</p></li>
# <li name="headline_img4" onclick="location.href='/media/view.asp?idx=97637';" onmouseout="start(4);" onmouseover="headline_news(4);"><p>MS 익스체인지에서 제로데이 발표되자 5분 만에 스캔 시작한 해커들</p></li>
# <li name="headline_img5" onclick="location.href='/media/view.asp?idx=97634';" onmouseout="start(5);" onmouseover="headline_news(5);"><p>RSA 컨퍼런스에서 발표한 솔라윈즈 CEO, “보안은 공동의 책임”</p></li>
# </ul>
# </div>
# <div id="headline4">
# <div class="headline_big_img" onclick="location.href='/media/view.asp?idx=97634';" style="background: #fff url(/media/upFiles2/2021/05/610421023_8678.jpg) center center no-repeat;background-size:cover;"><p class="gradient"><a href="/media/view.asp?idx=97634">RSA 컨퍼런스에서 발표한 솔라윈즈 CEO, “보안...</a></p></div>
# <ul class="headline_small_img">
# <li name="headline_img1" onclick="location.href='/media/view.asp?idx=97673';" onmouseout="start(1);" onmouseover="headline_news(1);"><p>[황민주 보안에세이] 시간의 숙성과 지능형 지속공격의 관계</p></li>
# <li name="headline_img2" onclick="location.href='/media/view.asp?idx=97635';" onmouseout="start(2);" onmouseover="headline_news(2);"><p>[보.알.남] 나쁜 인공지능 만들기, 데이터 포이즈닝</p></li>
# <li name="headline_img3" onclick="location.href='/media/view.asp?idx=97638';" onmouseout="start(3);" onmouseover="headline_news(3);"><p>[한국정보보호학회 칼럼] 융합산업과 IoBE(Internet of Blend...</p></li>
# <li name="headline_img4" onclick="location.href='/media/view.asp?idx=97637';" onmouseout="start(4);" onmouseover="headline_news(4);"><p>MS 익스체인지에서 제로데이 발표되자 5분 만에 스캔 시작한 해커들</p></li>
# <li name="headline_img5" onclick="location.href='/media/view.asp?idx=97634';" onmouseout="start(5);" onmouseover="headline_news(5);"><p>RSA 컨퍼런스에서 발표한 솔라윈즈 CEO, “보안은 공동의 책임”</p></li>
# </ul>
# </div>
# </div>
# <script language="JavaScript">
# function headline_news(num){
# 	if (num==1){
# 		headline0.style.display="";
# 		headline1.style.display="none";
# 		headline2.style.display="none";
# 		headline3.style.display="none";
# 		headline4.style.display="none";
# 		document.getElementsByName("headline_img1")[0].style.backgroundColor="#359BED";
# 		document.getElementsByName("headline_img1")[0].style.color="#FFFFFF";
# 	}
# 	if (num==2){
# 		headline0.style.display="none";
# 		headline1.style.display="";
# 		headline2.style.display="none";
# 		headline3.style.display="none";
# 		headline4.style.display="none";
# 		document.getElementsByName("headline_img2")[1].style.backgroundColor="#359BED";
# 		document.getElementsByName("headline_img2")[1].style.color="#FFFFFF";
#
# 	}
# 	if (num==3){
# 		headline0.style.display="none";
# 		headline1.style.display="none";
# 		headline2.style.display="";
# 		headline3.style.display="none";
# 		headline4.style.display="none";
# 		document.getElementsByName("headline_img3")[2].style.backgroundColor="#359BED";
# 		document.getElementsByName("headline_img3")[2].style.color="#FFFFFF";
# 	}
# 	if (num==4){
# 		headline0.style.display="none";
# 		headline1.style.display="none";
# 		headline2.style.display="none";
# 		headline3.style.display="";
# 		headline4.style.display="none";
# 		document.getElementsByName("headline_img4")[3].style.backgroundColor="#359BED";
# 		document.getElementsByName("headline_img4")[3].style.color="#FFFFFF";
# 	}
# 	if (num==5){
# 		headline0.style.display="none";
# 		headline1.style.display="none";
# 		headline2.style.display="none";
# 		headline3.style.display="none";
# 		headline4.style.display="";
# 		document.getElementsByName("headline_img5")[4].style.backgroundColor="#359BED";
# 		document.getElementsByName("headline_img5")[4].style.color="#FFFFFF";
# 	}
# }
#
#
# headline_news(1);
# n=1;
# $(function(){
# 	var autoRoll=setInterval(function(){
# 		headline_news(n);
# 		n++;
#
# 		if (n>5){
# 			n=1;
# 		}
# 	},3000);
#
# 	$(".headline_small_img").mouseover(function(){
# 		clearInterval(autoRoll);
# 	});
# });
#
#
# function start(num){
# 	var timer=setInterval(function(){
# 		headline_news(num);
# 		num++;
#
# 		if (num>5){
# 			num=1;
# 		}
# 	},3000);
#
# 	$(".headline_small_img").mouseover(function(){
# 		clearInterval(timer);
# 	});
# }
#
#
#
# </script>
# <article class="fast_news">
# <div style="width:50px; height:32px; padding-top:10px; font-family:'Noto Sans KR'; font-size:15px; color:#FFFFFF; background-color:#D80911; float:left;">   속보</div>
# <div class="contType01">
# <div class="list">
# <div class="listIn">
# <ul tx="-5012">
# <li index="0"><a href="/media/view.asp?idx=97640">[긴급] KB국민은행, 모바일·PC 인터넷 뱅킹 서...</a></li>
# <li index="1"><a href="/media/view.asp?idx=97556">랜섬웨어+기밀유출+디도스 ‘삼중 협박’ 아바돈 랜섬...</a></li>
# <li index="2"><a href="/media/view.asp?idx=97544">美 송유관 감염 사태로 더 커진 랜섬웨어 공포! 기...</a></li>
# <li index="3"><a href="/media/view.asp?idx=97543">유틸리티 프로그램 위장해 악성코드 유포하는 피싱 사...</a></li>
# <li index="4"><a href="/media/view.asp?idx=97542">‘장학금 신청’ 관련 내용 피싱 메일 연이어 유포!...</a></li>
# <li index="5"><a href="/media/view.asp?idx=97353">TeamT5, 블랙햇아시아에서 ‘김수키’ 그룹 최신...</a></li>
# <li index="6"><a href="/media/view.asp?idx=97294">더 악독해진 랜섬웨어 조직, 해킹한 유출 정보를 경...</a></li>
# <li index="7"><a href="/media/view.asp?idx=97301">UNC2529 그룹, 3개 멀웨어 조합해 대규모 피...</a></li>
# <li index="8"><a href="/media/view.asp?idx=97293">미국 최대 송유관 운영사까지 랜섬웨어 공격에 멈췄다...</a></li>
# <li index="9"><a href="/media/view.asp?idx=97232">[긴급] “아빠 나 폰 액정 깨졌어”라는 메시지? ...</a></li>
# </ul>
# </div>
# </div>
# </div>
# </article>
# <article class="main_banner">
# <ul>
# <li><a href="/custom/banner_page.asp?idx=823" onfocus="this.blur();" target="_blank"><img alt="bob 10기 모집" src="/images/banner/bob_10_BN_335px_100px(0).jpg"/></a></li><li><a href="/custom/banner_page.asp?idx=801" onfocus="this.blur();" target="_blank"><img alt="시큐5월특집" src="/images/banner/osint_210503_247x78.gif"/></a></li><li><a href="/custom/banner_page.asp?idx=605" onfocus="this.blur();" target="_blank"><img alt="" src="/images/banner/보안뉴스배너_274x78.gif"/></a></li><li><a href="/custom/banner_page.asp?idx=606" onfocus="this.blur();" target="_blank"><img alt="" src="/images/banner/isc2_274x78.gif"/></a></li>
# </ul>
# </article><article class="section2">
# <ul>
# <li>
# <div class="section_title2"><a href="/media/list.asp?mkind=1"><font color="#bc0e25">SECURITY</font></a></div>
# <div class="section_news2">
# <a href="/media/view.asp?idx=97675&amp;mkind=1">
# <img src="/media/upFiles2/2021/05/19935263_main.jpg">
# <p class="t1">중소기업에 간편한 ‘무설치형 인증서’ 도입 지원한다</p></img></a>
# <p class="t2"><a href="/media/view.asp?idx=97675&amp;mkind=1">그동안 ActiveX, exe 등 SW 설치형 전자서명 서비스를 이용하던...</a></p>
# <a href="/media/view.asp?idx=97676&amp;mkind=1"><p class="t3">[인사] 과학기술정보통신부</p></a>
# <a href="/media/view.asp?idx=97674&amp;mkind=1"><p class="t3">화웨이, 2021 가트너 피어 인사이트 스토리지 부문 ‘고객의 선...</p></a>
# <a href="/media/view.asp?idx=97640&amp;mkind=1"><p class="t3">[긴급] KB국민은행, 모바일·PC 인터넷 뱅킹 서비스 일시 중단</p></a>
# <a href="/media/view.asp?idx=97639&amp;mkind=1"><p class="t3">HM COMPANY, 세계보안엑스포에서 데이터 리뷰 플랫폼 선보이...</p></a>
# </div>
# </li>
# <li>
# <div class="section_title2"><a href="/media/list.asp?mkind=2"><font color="#bc0e25">IT</font></a></div>
# <div class="section_news2">
# <a href="/media/view.asp?idx=97662&amp;mkind=2">
# <img src="/media/upFiles2/2021/05/5-271(295).jpg">
# <p class="t1">삼성전자, C랩 과제 4개 스타트업 창업 지원</p></img></a>
# <p class="t2"><a href="/media/view.asp?idx=97662&amp;mkind=2">삼성전자가 사내벤처 육성 프로그램 ‘C랩 인사이드’의 4개 우수 과제 스...</a></p>
# <a href="/media/view.asp?idx=97663&amp;mkind=2"><p class="t3">국토부, 스마트 물류기술 활용 ‘디지털 물류실증단지’ 조성 본격 ...</p></a>
# <a href="/media/view.asp?idx=97664&amp;mkind=2"><p class="t3">국토부, 6월부터 고해상도 항공사진 서비스로 국토의 변화상 한눈에...</p></a>
# <a href="/media/view.asp?idx=97666&amp;mkind=2"><p class="t3">북한 산림공간정보 구축에도 AI 활용한다</p></a>
# <a href="/media/view.asp?idx=97667&amp;mkind=2"><p class="t3">한-유럽, 그린·디지털 기술협력에 머리 맞댄다</p></a>
# </div>
# </li>
# <li>
# <div class="section_title2"><a href="/media/list.asp?mkind=4"><font color="#bc0e25">SAFETY</font></a></div>
# <div class="section_news2">
# <a href="/media/view.asp?idx=97665&amp;mkind=4">
# <img src="/media/upFiles2/2021/05/5-274(295).jpg">
# <p class="t1">소방청, 혁신적인 배낭소방호스 전술 실험 성공</p></img></a>
# <p class="t2"><a href="/media/view.asp?idx=97665&amp;mkind=4">충청남도는 소방호스를 펼쳐 화재진압을 할 수 있는 특수소방호스배낭 개발에...</a></p>
# <a href="/media/view.asp?idx=97672&amp;mkind=4"><p class="t3">소방청, ‘제20회 대한민국 안전대상’ 공모</p></a>
# <a href="/media/view.asp?idx=97609&amp;mkind=4"><p class="t3">안성시, 보행자 교통안전 위한 LED 바닥 보행신호등 설치</p></a>
# <a href="/media/view.asp?idx=97615&amp;mkind=4"><p class="t3">공주시, 498억 투입해 자연재해예방사업 추진</p></a>
# <a href="/media/view.asp?idx=97577&amp;mkind=4"><p class="t3">국토부, 국민과 함께하는 도로안전 지킴이 ‘도로안전 국민참여단’ ...</p></a>
# </div>
# </li>
# <li>
# <div class="section_title2"><a href="/securityworld/"><font color="#bc0e25"><i>Security World</i></font></a></div>
# <div class="section_news2">
# <a href="/media/view.asp?idx=97632&amp;mkind=5">
# <img src="/media/upFiles2/2021/05/21052004ss.JPG">
# <p class="t1">효성인포메이션시스템, 가상화 기반의 미래지향적 ‘스마트시티 통합플...</p></img></a>
# <p class="t2"><a href="/media/view.asp?idx=97632&amp;mkind=5">통합 ICT 인프라 솔루션 전문기업 효성인포메이션시스템(대표 양정규)이 ...</a></p>
# <a href="/media/view.asp?idx=97605&amp;mkind=5"><p class="t3">한국씨텍, 세계보안엑스포에서 다양한 형태의 포지셔닝 카메라로 주목</p></a>
# <a href="/media/view.asp?idx=97598&amp;mkind=5"><p class="t3">AIS테크놀러지, 경기도 의정부시에 IT 인프라 공급</p></a>
# <a href="/media/view.asp?idx=97590&amp;mkind=5"><p class="t3">유니온커뮤니티, 개인정보 유출 원천 차단 시스템 주목</p></a>
# <a href="/media/view.asp?idx=97587&amp;mkind=5"><p class="t3">ADT캡스, 한국수력원자력 OT/ICS 보안 컨설팅 사업 수주</p></a>
# </div>
# </li>
# </ul>
# </article>
# <div class="line1"></div>
# <div id="body_left">
# <!--########## body left Start ##########-->
# <!--include file="main_contents/main_card.asp"-->
# <iframe frameborder="0" height="188" marginheight="0" marginwidth="0" src="https://www.youtube.com/embed/hxPncFbqAzo" style="border-bottom:1px solid #DDDDDD;" width="335"></iframe>
# <iframe frameborder="0" height="320" id="main_banner_B1" name="main_banner_B1" src="/main_contents/main_banner_B1.asp" style="margin:10px 0 0 0;" width="335"></iframe>
# <iframe frameborder="0" height="100" id="main_banner_B2" name="main_banner_B2" src="/main_contents/main_banner_B2.asp" style="margin:6px 0 0 0;" width="335"></iframe>
# <iframe frameborder="0" height="100" id="main_banner_B3" name="main_banner_B3" src="/main_contents/main_banner_B3.asp" style="margin:6px 0 6px 0;" width="335"></iframe>
# <div id="main_contents_area">
# <div id="main_contents_title" onclick="location.href='/media/s_list.asp?skind=K';"><span><font color="#bc0e25">인사</font>ㆍ부고</span></div>
# <div style="text-align:left;"><a href="/media/view.asp?idx=97676&amp;skind=K" onfocus="this.blur();" style="margin-left:10px;font-size:15px;line-height:32px;"><b>[인사] 과학기술정보통신부</b></a></div><div style="text-align:left;"><a href="/media/view.asp?idx=97603&amp;skind=K" onfocus="this.blur();" style="margin-left:10px;font-size:15px;line-height:32px;"><b>[인사] 스카이데일리</b></a></div><div style="text-align:left;"><a href="/media/view.asp?idx=97600&amp;skind=K" onfocus="this.blur();" style="margin-left:10px;font-size:15px;line-height:32px;"><b>[부고] 주용완 강릉원주대 교수 부친상</b></a></div><div style="text-align:left;"><a href="/media/view.asp?idx=97586&amp;skind=K" onfocus="this.blur();" style="margin-left:10px;font-size:15px;line-height:32px;"><b>[인사] 과학기술정보통신부 과장급 인사</b></a></div><div style="text-align:left;"><a href="/media/view.asp?idx=97499&amp;skind=K" onfocus="this.blur();" style="margin-left:10px;font-size:15px;line-height:32px;"><b>[인사] 과학기술정보통신부 고위공무원 인사 발령</b></a></div><div style="text-align:left;"><a href="/media/view.asp?idx=97236&amp;skind=K" onfocus="this.blur();" style="margin-left:10px;font-size:15px;line-height:32px;"><b>[인사] 한국미디어네트워크 </b></a></div>
# </div><div id="sub_section_area">
# <div id="sub_section_title" onclick="location.href='/media/s_list.asp?skind=7';"><span>기획<font color="#bc0e25">특집</font></span></div>
# <div id="sub_section">
# <div class="sub_1"><a href="/media/view.asp?idx=97050&amp;skind=7"><img alt="" height="65" src="/media/upFiles2/2021/05/21050302ss.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97050&amp;skind=7"><b>홈 CCTV 카메라 5종, 기자의 DIY 설치 도전기 </b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=97019&amp;skind=7"><img alt="" height="65" src="/media/upFiles2/2021/04/osint_01_th.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97019&amp;skind=7"><b>[2021 OSINT 리포트] 익명성 악용하는 사이버 범죄자,...</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=97008&amp;skind=7"><img alt="" height="65" src="/media/upFiles2/2021/04/20210503SECONMAIN-S.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97008&amp;skind=7"><b>대한민국 보안인의 축제 ‘제20회 세계보안엑스포(SECON &amp;...</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=96075&amp;skind=7"><img alt="" height="65" src="/media/upFiles2/2021/03/21047941_main.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=96075&amp;skind=7"><b>[2021 보안리포트] 언택트 시대 블루오션, 이미지내 개인정...</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=96029&amp;skind=7"><img alt="" height="65" src="/media/upFiles2/2021/03/21033002ss.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=96029&amp;skind=7"><b>영상보안 분야 SoC칩 대란, 다양한 해결책을 모색하다  </b></a>
# </div>
# </div>
# </div>
# <div id="sub_section_area">
# <div id="sub_section_title" onclick="location.href='/search/news_total.asp?search=title&amp;find=주말판';"><span><font color="#bc0e25">주말판</font></span></div>
# <div id="sub_section">
# <div class="sub_1"><a href="/media/view.asp?idx=97037"><img alt="" height="65" src="/media/upFiles2/2021/05/api-thumb-0501.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97037"><b> 현 시점 보안 업계가 직시해야 하는 ‘진짜 현실’ 7가지</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=96851"><img alt="" height="65" src="/media/upFiles2/2021/04/rec-thumb-0424.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=96851"><b> 취약점 보고서를 효과적으로 처리하기 위한 5가지 절차</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=96635"><img alt="" height="65" src="/media/upFiles2/2021/04/7-thumb-0417.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=96635"><b> 일반인들에게 권장해줄 만한 프라이버시 보호 앱 7</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=96401"><img alt="" height="65" src="/media/upFiles2/2021/04/log-thumb-0410.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=96401"><b> 더 나은 로그 관리를 위한 실전 어드바이스 9</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=96190"><img alt="" height="65" src="/media/upFiles2/2021/04/chip-thumb-0403.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=96190"><b> 데이터 홍수의 시대, 다가오는 데이터 스토리지 기술 5</b></a>
# </div>
# </div>
# </div>
# <!--########## body left end ##########-->
# </div>
# <div id="body_center">
# <!--########## body center Start ##########-->
# <div id="sub_section_area">
# <div id="sub_section_title" onclick="location.href='/media/s_list.asp?skind=D';"><span><font color="#bc0e25">국제</font></span></div>
# <div id="sub_section">
# <div class="sub_1"><a href="/media/view.asp?idx=97637&amp;skind=D"><img alt="" height="65" src="/media/upFiles2/2021/05/time-thumb-0520.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97637&amp;skind=D"><b>MS 익스체인지에서 제로데이 발표되자 5분 만에 스캔 시작한 ...</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=97634&amp;skind=D"><img alt="" height="65" src="/media/upFiles2/2021/05/solwind-thmb-0520.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97634&amp;skind=D"><b>RSA 컨퍼런스에서 발표한 솔라윈즈 CEO, “보안은 공동의 ...</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=97633&amp;skind=D"><img alt="" height="65" src="/media/upFiles2/2021/05/hack-thumb-0520.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97633&amp;skind=D"><b>코발트 스트라이크, 현재 공격자들이 가장 선호하는 침투 도구</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=97604&amp;skind=D"><img alt="" height="65" src="/media/upFiles2/2021/05/solar-thumb-0518.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97604&amp;skind=D"><b>RSA 컨퍼런스에 강연자로 출격하는 솔라윈즈 CEO, 어떤 이...</b></a>
# </div>
# </div>
# </div>
# <div id="sub_section_area">
# <div id="sub_section_title" onclick="location.href='/media/s_list.asp?skind=6';"><span><font color="#bc0e25">공공</font>ㆍ정책</span></div>
# <div id="sub_section">
# <div class="sub_1"><a href="/media/view.asp?idx=97636&amp;skind=6"><img alt="" height="65" src="/media/upFiles2/2021/05/pipc_20210520_th.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97636&amp;skind=6"><b>가명정보 결합기관 협의회 개최... 결합 활성화 앞장선다</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=97606&amp;skind=6"><img alt="" height="65" src="/media/upFiles2/2021/05/20210519ran-s.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97606&amp;skind=6"><b>기업의 랜섬웨어 공포증 확산!  과기정통부, ‘랜섬웨어 대응 ...</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=97540&amp;skind=6"><img alt="" height="65" src="/media/upFiles2/2021/05/20210516ai-s.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97540&amp;skind=6"><b>‘2020년 인공지능 그랜드 챌린지’ 서막이 열린다! 총 20...</b></a>
# </div>
# </div>
# </div>
# <div id="sub_section_area">
# <div id="sub_section_title" onclick="location.href='/media/s_list.asp?skind=3';"><span><font color="#bc0e25">인터뷰</font>ㆍ오피니언</span></div>
# <div id="sub_section">
# <div class="sub_1"><a href="/media/view.asp?idx=97673&amp;skind=3"><img alt="" height="65" src="/media/upFiles2/2021/05/20210521essaymain-s.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97673&amp;skind=3"><b>[황민주 보안에세이] 시간의 숙성과 지능형 지속공격의 관계</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=97638&amp;skind=3"><img alt="" height="65" src="/media/upFiles2/2021/05/kii_20210520_th.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97638&amp;skind=3"><b>[한국정보보호학회 칼럼] 융합산업과 IoBE(Internet ...</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=97595&amp;skind=3"><img alt="" height="65" src="/media/upFiles2/2021/05/20552496_main.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97595&amp;skind=3"><b>[CSRC@KAIST 차세대보안R&amp;D리포트] 1년간의 여정을 ...</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=97361&amp;skind=3"><img alt="" height="65" src="/media/upFiles2/2021/05/21051701ss.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97361&amp;skind=3"><b>박성면 한국안전경영연구원 원장, “CCTV 관제 전문인력 양성...</b></a>
# </div>
# </div>
# </div>
# <!--include file="main_contents/main_news04.asp"-->
# <div id="sub_section_area">
# <div id="sub_section_title" onclick="location.href='/search/news_total.asp?search=title&amp;find=보.알.남';"><span><font color="#bc0e25">보안</font>을 알려주는 남자</span></div>
# <div id="sub_section">
# <div class="sub_1"><a href="/media/view.asp?idx=97635"><img alt="" height="65" src="/media/upFiles2/2021/05/poison_20210520_th.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97635"><b> 나쁜 인공지능 만들기, 데이터 포이즈닝</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=97036"><img alt="" height="65" src="/media/upFiles2/2021/05/3333333333.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97036"><b> 가벼운 장난 같지만 엄연한 범죄, 디페이스 공격</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=96192"><img alt="" height="65" src="/media/upFiles2/2021/04/typo_20210405_main_th.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=96192"><b> 단순한 눈속임을 넘어 공급망 공격까지, 타이포스쿼팅</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=95773"><img alt="" height="65" src="/media/upFiles2/2021/03/1111111_20210322_main_th.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=95773"><b> 인공지능 시대를 위한 암호화 기술, 동형암호</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=94776"><img alt="" height="65" src="/media/upFiles2/2021/02/vdftrr_20210208_mainth.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=94776"><b> 사용자의 눈을 피해 침투한다, 파일리스 공격</b></a>
# </div>
# </div>
# </div>
# <div id="sub_section_area">
# <div id="sub_section_title" onclick="location.href='/security_contents/info/list.asp';"><span><font color="#bc0e25">시큐리티</font> 콘텐츠</span></div>
# <div id="main_contents_list"><span class="main_contents_icon"><img '="" src="/security_contents/img/pdf.gif"/></span><a class="main_contents_txt" href="/security_contents/info/view.asp?idx=810&amp;code=01012" onfocus="this.blur();">2020년 4분기 사이버 위협 동향 보고서</a></div><div id="main_contents_list"><span class="main_contents_icon"><img '="" src="/security_contents/img/pdf.gif"/></span><a class="main_contents_txt" href="/security_contents/info/view.asp?idx=809&amp;code=02019" onfocus="this.blur();">악성코드 은닉사이트 탐지 동향 보고서(202..</a></div><div id="main_contents_list"><span class="main_contents_icon"><img '="" src="/security_contents/img/pdf.gif"/></span><a class="main_contents_txt" href="/security_contents/info/view.asp?idx=808&amp;code=02019" onfocus="this.blur();">2020 Security Magazine</a></div><div id="main_contents_list"><span class="main_contents_icon"><img '="" src="/security_contents/img/pdf.gif"/></span><a class="main_contents_txt" href="/security_contents/info/view.asp?idx=807&amp;code=06046" onfocus="this.blur();">클라우드 취약점 점검 가이드-보안설정(CCE..</a></div><div id="main_contents_list"><span class="main_contents_icon"><img '="" src="/security_contents/img/pdf.gif"/></span><a class="main_contents_txt" href="/security_contents/info/view.asp?idx=806&amp;code=06046" onfocus="this.blur();">자율주행자동차 윤리가이드라인</a></div><div id="main_contents_list"><span class="main_contents_icon"><img '="" src="/security_contents/img/pdf.gif"/></span><a class="main_contents_txt" href="/security_contents/info/view.asp?idx=805&amp;code=06046" onfocus="this.blur();">레벨4 자율주행자동차 제작 및 안전 가이드라..</a></div><div id="main_contents_list"><span class="main_contents_icon"><img '="" src="/security_contents/img/pdf.gif"/></span><a class="main_contents_txt" href="/security_contents/info/view.asp?idx=803&amp;code=06046" onfocus="this.blur();">국토부 자동차 사이버보안 가이드라인</a></div><div id="main_contents_list"><span class="main_contents_icon"><img '="" src="/security_contents/img/pdf.gif"/></span><a class="main_contents_txt" href="/security_contents/info/view.asp?idx=802&amp;code=01005" onfocus="this.blur();">개인정보보호 실천가이드 Vol.10 데이터3..</a></div><div id="main_contents_list"><span class="main_contents_icon"><img '="" src="/security_contents/img/pdf.gif"/></span><a class="main_contents_txt" href="/security_contents/info/view.asp?idx=801&amp;code=06046" onfocus="this.blur();">[ISEC 2020] DevOps ~ Con..</a></div>
# </div>
# <div id="newsletter_area">
# <div id="newsletter_title" onclick="location.href='/newsletter/';"><span><font color="#bc0e25">뉴스레터 신청</font>ㆍ친구에게 추천하기</span></div>
# <div class="letter_txt">매일 다양한 보안뉴스 뉴스레터 및 최신 보안관련<br/>정보 수신과 친구에게 추천 하시려면 클릭하세요.</div>
# <div class="letter1"><input class="text" id="m_email" maxlength="80" name="m_email" onclick="location.href='/newsletter/';" type="text" value="E-mail"/></div>
# <div class="letter2"><img alt="" src="images/body/letter_icon.gif"/></div>
# </div>
# <!--########## body center end ##########-->
# </div>
# <div id="body_right">
# <!--########## body right Start ##########-->
# <script type="text/javascript">
# jQuery(function(jQuery){
# 	jQuery(".tab-newslist").hide();
# 	jQuery(".tab-newslist").eq(0).show();
#
# 	jQuery(".tab-newstit li").each(function(index){
# 		$(this).click(function(){
# 			jQuery(".tab-newstit li span").removeClass("on");
# 			var idx = jQuery(this).index();
# 			jQuery(".tab-newstit li").eq(index).find("span").addClass("on");
# 			jQuery(".tab-newslist").hide();
# 			jQuery(".tab-newslist").eq(idx).show();
# 		});
# 	});
# });
# </script>
# <div id="seq">
# <ul class="tab-newstit">
# <li><span class="on" href="#sec1" id="sec1">조회순</span></li>
# <li><span href="#sec2" id="sec2">추천순</span></li>
# <li><span href="#sec3" id="sec2">스크랩순</span></li>
# </ul>
# <ul class="tab-newslist"><!-- 조회순 -->
# <li><p class="news_count" style="color:#B71E1E;">1</p>
# <a href="/media/view.asp?idx=97640"><span><img alt="" src="/media/upFiles2/2021/05/1thththththth.jpg"/></span>
# <span>[긴급] KB국민은행, 모바일·PC 인터넷 뱅킹 서비스 일시 ...</span></a>
# </li>
# <li><p class="news_count" style="color:#B71E1E;">2</p>
# <a href="/media/view.asp?idx=97606"><span><img alt="" src="/media/upFiles2/2021/05/20210519ran-s.jpg"/></span>
# <span>기업의 랜섬웨어 공포증 확산!  과기정통부, ‘랜섬웨어 대응 ...</span></a>
# </li>
# <li><p class="news_count" style="color:#B71E1E;">3</p>
# <a href="/media/view.asp?idx=97633"><span><img alt="" src="/media/upFiles2/2021/05/hack-thumb-0520.jpg"/></span>
# <span>코발트 스트라이크, 현재 공격자들이 가장 선호하는 침투 도구</span></a>
# </li>
# <li><p class="news_count">4</p>
# <a href="/media/view.asp?idx=97629"><span><img alt="" src="/media/upFiles2/2021/05/aka_20210520_th.jpg"/></span>
# <span>2020년 금융업계 노린 크리덴셜 스터핑 공격 45% 증가.....</span></a>
# </li>
# <li><p class="news_count">5</p>
# <a href="/media/view.asp?idx=97612"><span><img alt="" src="/media/upFiles2/2021/05/5-233(295).jpg"/></span>
# <span>한국서부발전, 로봇안전기술 개발 ‘본격화’</span></a>
# </li>
# </ul>
# <ul class="tab-newslist"><!-- 추천순 -->
# <li><p class="news_count" style="color:#B71E1E;">1</p>
# <a href="/media/view.asp?idx=97595"><span><img alt="" src="/media/upFiles2/2021/05/20552496_main.jpg"/></span>
# <span>[CSRC@KAIST 차세대보안R&amp;D리포트] 1년간의 여정을 ...</span></a>
# </li>
# <li><p class="news_count" style="color:#B71E1E;">2</p>
# <a href="/media/view.asp?idx=97561"><span><img alt="" src="/media/upFiles2/2021/05/ai_01_th.jpg"/></span>
# <span>AI 보안 1기 석사학위를 노려라, 동국대 국제정보보호대학원 ...</span></a>
# </li>
# <li><p class="news_count" style="color:#B71E1E;">3</p>
# <a href="/media/view.asp?idx=97559"><span><img alt="" src="/media/upFiles2/2021/05/dark-thumb-0517.jpg"/></span>
# <span>콜로니얼 파이프라인 마비시킨 다크사이드, 서버 마비로 은퇴 선...</span></a>
# ...
# <span>랜섬웨어+기밀유출+디도스 ‘삼중 협박’ 아바돈 랜섬웨어, 한국...</span></a>
# </li>
# <li><p class="news_count">5</p>
# <a href="/media/view.asp?idx=97552"><span><img alt="" src="/media/upFiles2/2021/05/comp-thumb-0517.jpg"/></span>
# <span>브라우저 바꿔 접속해도 당신을 알아보게 해 주는 ‘스킴 플러딩...</span></a>
# </li>
# </ul>
# </div><div id="sub_section02_area">
# <div id="sub_section02_title" onclick="location.href='/search/news_list.asp?search=key_word&amp;find=피싱';"><span><font color="#bc0e25">피싱</font>ㆍ스미싱</span></div>
# <div id="sub_section02">
# <div class="sub_1"><a href="/media/view.asp?idx=97602"><img alt="" height="65" src="/media/upFiles2/2021/05/asec_051801_main.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97602"><b>네이버 웍스·메일플러그·하이웍스 등 기업 메일 사용자 노린 피...</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=97599"><img alt="" height="65" src="/media/upFiles2/2021/05/sms_20210518_2.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97599"><b>‘교통민원24’ 앱 설치로 위장한 스미싱 발견... 사용자 주...</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=97543"><img alt="" height="65" src="/media/upFiles2/2021/05/20210516AHN1-S.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97543"><b>유틸리티 프로그램 위장해 악성코드 유포하는 피싱 사이트 또 발...</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=97542"><img alt="" height="65" src="/media/upFiles2/2021/05/20210516ALYACM-S.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97542"><b>‘장학금 신청’ 관련 내용 피싱 메일 연이어 유포! 금융정보까...</b></a>
# </div>
# </div>
# </div>
# <div id="sub_section02_area" style="margin-bottom:21px;">
# <div id="sub_section02_title" onclick="location.href='/media/s_list.asp?skind=K';"><span><font color="#bc0e25">취약점 경고</font> 및 보안 업데이트</span></div>
# <div style="text-align:left;"><a href="/media/view.asp?idx=97640&amp;skind=5" style="margin-left:20px;font-size:15px;line-height:30px;"><b>[2021.05.20] [긴급] KB국민은행, 모바일...</b></a></div>
# <div style="text-align:left;"><a href="/media/view.asp?idx=97599&amp;skind=5" style="margin-left:20px;font-size:15px;line-height:30px;"><b>[2021.05.18] ‘교통민원24’ 앱 설치로 위...</b></a></div>
# <div style="text-align:left;"><a href="/media/view.asp?idx=97556&amp;skind=5" style="margin-left:20px;font-size:15px;line-height:30px;"><b>[2021.05.17] 랜섬웨어+기밀유출+디도스 ‘삼...</b></a></div>
# <div style="text-align:left;"><a href="/media/view.asp?idx=97544&amp;skind=5" style="margin-left:20px;font-size:15px;line-height:30px;"><b>[2021.05.17] 美 송유관 감염 사태로 더 커...</b></a></div>
# <div style="text-align:left;"><a href="/media/view.asp?idx=97543&amp;skind=5" style="margin-left:20px;font-size:15px;line-height:30px;"><b>[2021.05.17] 유틸리티 프로그램 위장해 악성...</b></a></div>
# </div><div id="sub_section02_area">
# <div id="sub_section02_title" onclick="location.href='/search/news_total.asp?search=title&amp;find=CSRC@KAIST';"><span><font color="#bc0e25">CSRC@KAIST</font> 차세대보안R&amp;D 리포트</span></div>
# <div id="sub_section02">
# <div class="sub_1"><a href="/media/view.asp?idx=97595"><img alt="" height="65" src="/media/upFiles2/2021/05/20552496_main.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97595"><b> 1년간의 여정을 마치며</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=97130"><img alt="" height="65" src="/media/upFiles2/2021/05/20509460_main.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=97130"><b> 인공지능 안전성과 정형 검증</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=96696"><img alt="" height="65" src="/media/upFiles2/2021/04/20803967_main.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=96696"><b> 데이터 공격 방어기법</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=96253"><img alt="" height="65" src="/media/upFiles2/2021/04/20614403_main.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=96253"><b> 랜섬웨어의 어제와 오늘</b></a>
# </div>
# <div class="sub_1"><a href="/media/view.asp?idx=95847"><img alt="" height="65" src="/media/upFiles2/2021/03/21420911_main.jpg" width="100"/></a></div>
# <div class="sub_2">
# <a class="sub_link" href="/media/view.asp?idx=95847"><b> Data-oriented Attack</b></a>
# </div>
# </div>
# </div>
# <script type="text/JavaScript">
# function fncChkSurvey() {
# var check=0;
# for(i=0;i<poll.poll_chek.length;i++) {
# if(poll.poll_chek[i].checked) {check=1;}
# }
# if(check<1) {alert('투표할 메뉴를 선택하세요'); return false;}
# return true;
# }
# </script>
# <div id="poll_title"><span>설문조사</span></div>
# <form action="/media/poll_ok.asp?idx=201" method="post" name="poll" onsubmit="return fncChkSurvey()">
# <table id="poll_table">
# <tr><td class="poll_q" colspan="2"><b>지난 5일 밤 발생한 카카오톡 장애로 인해 일명 ‘넷플릭스법’에 대한 관심이 다시금 높아지고 있는데요. 통신서비스 품질 유지 의무를 부과하고 있는 기업 가운데 가장 안정적인 서비스를 제공하는 부가통신사업자는 어디라고 생각하시나요? </b></td></tr>
# <tr><td><input name="poll_chek" type="radio" value="1"/></td>
# <td class="poll_item">네이버</td></tr>
# <tr><td><input name="poll_chek" type="radio" value="2"/></td>
# <td class="poll_item">카카오 </td></tr>
# <tr><td><input name="poll_chek" type="radio" value="3"/></td>
# <td class="poll_item">웨이브</td></tr>
# <tr><td><input name="poll_chek" type="radio" value="4"/></td>
# <td class="poll_item">넷플릭스 </td></tr>
# <tr><td><input name="poll_chek" type="radio" value="5"/></td>
# <td class="poll_item">구글 </td></tr>
# <tr><td><input name="poll_chek" type="radio" value="6"/></td>
# <td class="poll_item">페이스북</td></tr>
# <tr><td colspan="2">
# <input alt="투표하기" src="/media/images/right/poll_btn01.gif" type="image">      <a href="/media/poll_02.asp?idx=201"><img alt="" src="/media/images/right/poll_btn02.gif"/></a></input></td></tr>
# </table>
# </form>
# <!--########## body right end ##########-->
# </div>
# <div class="line2"></div>
# <!--########## bottom news Start ##########-->
# <article class="section">
# <ul>
# <li>
# <div class="section_title"><a href="https://www.boannews.com/search/news_total.asp?search=key_word&amp;find=%BB%E7%B0%C7%BB%E7%B0%ED">#사건사고</a></div>
# <div class="section_news">
# <a href="/media/view.asp?idx=97544">
# <img src="/media/upFiles2/2021/05/20210516ran-S.jpg">
# <p class="t1">美 송유관 감염 사태로 더 커진 랜섬웨어 공포! 기업의 9가지 보...</p></img></a>
# <p class="t2"><a href="/media/view.asp?idx=97544">미국 최대 송유관 운영사인 콜로니얼 파이프라인의 랜섬웨어 감염 사태가 일...</a></p>
# <a href="/media/view.asp?idx=97294"><p class="t3">더 악독해진 랜섬웨어 조직, 해킹...</p></a>
# <a href="/media/view.asp?idx=97232"><p class="t3">[긴급] “아빠 나 폰 액정 깨졌...</p></a>
# <a href="/media/view.asp?idx=97170"><p class="t3">카카오톡 장애 2시간 20분......</p></a>
# <a href="/media/view.asp?idx=97154"><p class="t3">카카오톡 채팅 및 PC버전 로그인...</p></a>
# </div>
# </li>
# <li>
# <div class="section_title"><a href="https://www.boannews.com/search/news_total.asp?search=title&amp;find=스마트폰보안">#스마트폰보안</a></div>
# <div class="section_news">
# <a href="/media/view.asp?idx=97599">
# <img src="/media/upFiles2/2021/05/sms_20210518_2.jpg">
# <p class="t1">‘교통민원24’ 앱 설치로 위장한 스미싱 발견... 사용자 주의 ...</p></img></a>
# <p class="t2"><a href="/media/view.asp?idx=97599">스미싱 수법은 날로 교묘해지고 있다. 택배 발송 등을 사칭해 사용자를 속...</a></p>
# <a href="/media/view.asp?idx=96608"><p class="t3">URL 클릭 유도하는 스미싱 공격...</p></a>
# <a href="/media/view.asp?idx=96400"><p class="t3">타인에 의한 구글 플레이 무단결제...</p></a>
# <a href="/media/view.asp?idx=96091"><p class="t3">스마트폰 해킹 막아라!  믿고 쓰...</p></a>
# <a href="/media/view.asp?idx=96130"><p class="t3">해커의 침투지점 될 수 있는 공공...</p></a>
# </div>
# </li>
# <li>
# <div class="section_title"><a href="https://www.boannews.com/search/news_total.asp?search=title&amp;find=다크웹">#다크웹</a></div>
# <div class="section_news">
# <a href="/media/view.asp?idx=97597">
# <img src="/media/upFiles2/2021/05/mark-thumb-0518.jpg">
# <p class="t1">다크웹 조사했더니 MS의 소프트웨어 익스플로잇 수요 가장 높아</p></img></a>
# <p class="t2"><a href="/media/view.asp?idx=97597">CVE는 보안 전문가들의 보안 취약점 관리를 위한 일련 번호이기도 하지만...</a></p>
# <a href="/media/view.asp?idx=97556"><p class="t3">랜섬웨어+기밀유출+디도스 ‘삼중 ...</p></a>
# <a href="/media/view.asp?idx=97559"><p class="t3">콜로니얼 파이프라인 마비시킨 다크...</p></a>
# <a href="/media/view.asp?idx=97226"><p class="t3">코로나19 장기화로 ‘생계형 해킹...</p></a>
# <a href="/media/view.asp?idx=97104"><p class="t3">‘암호화폐를 훔치는 것만이 돈 버...</p></a>
# </div>
# </li>
# <li>
# <div class="section_title"><a href="https://www.boannews.com/search/news_total.asp?search=title&amp;find=세계보안엑스포">#세계보안엑스포</a></div>
# <div class="section_news">
# <a href="/media/view.asp?idx=97639">
# <img src="/media/upFiles2/2021/05/111112121212121212123tttttt.jpg">
# <p class="t1">HM COMPANY, 세계보안엑스포에서 데이터 리뷰 플랫폼 선보이...</p></img></a>
# <p class="t2"><a href="/media/view.asp?idx=97639">감사 및 정책 위험 진단 전문 기업 HM COMPANY(대표 조근호)가 ...</a></p>
# <a href="/media/view.asp?idx=97605"><p class="t3">한국씨텍, 세계보안엑스포에서 다양...</p></a>
# <a href="/media/view.asp?idx=97601"><p class="t3">한국보안인증, 세계보안엑스포에서 ...</p></a>
# <a href="/media/view.asp?idx=97560"><p class="t3">이수시스템, ‘SECON &amp; eG...</p></a>
# <a href="/media/view.asp?idx=97541"><p class="t3">[포토뉴스] 제20회 세계보안엑스...</p></a>
# </div>
# </li>
# </ul>
# </article>
# <!--########## bottom news end ##########-->
# </div>
# </div>
# <div id="bottom">
# <div id="main_news">
# <ul>
# <li><a href="/media/view.asp?idx=97673&amp;kind=36"><img alt="" height="160" src="/media/upFiles2/2021/05/20210521essaymain-s.jpg" width="250"/></a>
# <p><a href="/media/view.asp?idx=97673&amp;kind=36"><font color="#282828">[황민주 보안에세이] 시간의 숙성과 지능형 지속공격의 ...</font></a></p></li>
# <li><a href="/media/view.asp?idx=97635&amp;kind=15"><img alt="" height="160" src="/media/upFiles2/2021/05/poison_20210520_th.jpg" width="250"/></a>
# <p><a href="/media/view.asp?idx=97635&amp;kind=15"><font color="#282828">[보.알.남] 나쁜 인공지능 만들기, 데이터 포이즈닝</font></a></p></li>
# <li><a href="/media/view.asp?idx=97638&amp;kind=6"><img alt="" height="160" src="/media/upFiles2/2021/05/kii_20210520_th.jpg" width="250"/></a>
# <p><a href="/media/view.asp?idx=97638&amp;kind=6"><font color="#282828">[한국정보보호학회 칼럼] 융합산업과 IoBE(Inter...</font></a></p></li>
# <li><a href="/media/view.asp?idx=97637&amp;kind=14"><img alt="" height="160" src="/media/upFiles2/2021/05/time-thumb-0520.jpg" width="250"/></a>
# <p><a href="/media/view.asp?idx=97637&amp;kind=14"><font color="#282828">MS 익스체인지에서 제로데이 발표되자 5분 만에 스캔 ...</font></a></p></li>
# </ul>
# </div>
# <div id="main_news">
# <ul>
# <li><a href="/media/view.asp?idx=97634&amp;kind=14"><img alt="" height="160" src="/media/upFiles2/2021/05/solwind-thmb-0520.jpg" width="250"/></a>
# <p><a href="/media/view.asp?idx=97634&amp;kind=14"><font color="#282828">RSA 컨퍼런스에서 발표한 솔라윈즈 CEO, “보안은 ...</font></a></p></li>
# <li><a href="/media/view.asp?idx=97633&amp;kind=14"><img alt="" height="160" src="/media/upFiles2/2021/05/hack-thumb-0520.jpg" width="250"/></a>
# <p><a href="/media/view.asp?idx=97633&amp;kind=14"><font color="#282828">코발트 스트라이크, 현재 공격자들이 가장 선호하는 침투...</font></a></p></li>
# <li><a href="/media/view.asp?idx=97629&amp;kind=13"><img alt="" height="160" src="/media/upFiles2/2021/05/aka_20210520_th.jpg" width="250"/></a>
# <p><a href="/media/view.asp?idx=97629&amp;kind=13"><font color="#282828">2020년 금융업계 노린 크리덴셜 스터핑 공격 45% ...</font></a></p></li>
# <li><a href="/media/view.asp?idx=97595&amp;kind=56"><img alt="" height="160" src="/media/upFiles2/2021/05/20552496_main.jpg" width="250"/></a>
# <p><a href="/media/view.asp?idx=97595&amp;kind=56"><font color="#282828">[CSRC@KAIST 차세대보안R&amp;D리포트] 1년간의 ...</font></a></p></li>
# </ul>
# </div>
# </div>
# <div id="copyright">
# <ul>
# <li><a href="http://www.thebn.co.kr" target="_blank">회사소개</a><span>|</span></li>
# <li><a href="/custom/ad_info01.asp?kind=9">광고안내</a><span>|</span></li>
# <li><a href="/ad_info/ad_info02.asp?kind=02">이용약관</a><span>|</span></li>
# <li class="bottom_menu1"><a href="/ad_info/ad_info03.asp?kind=03">개인정보 처리방침</a><span>|</span></li>
# <li><a href="/ad_info/ad_info04.asp?kind=04">청소년 보호정책</a><span>|</span></li>
# <li><a href="/custom/customer_center.asp?kind=8">고객센터</a><span>|</span></li>
# <li><a href="/custom/company_info05.asp?kind=10">제휴안내</a><span>|</span></li>
# <li><a href="http://www.infothebooks.com" target="_blank">관련서적</a><span>|</span></li>
# <li><img alt="" src="/images/new/rss.gif"> <a href="/custom/news_rss.asp" onfocus="this.blur();">RSS 서비스</a><span>|</span></img></li>
# <li><font color="#5f5f5f">  발행인: 최정식  |  편집인: 최소영  |  청소년보호책임자: 최소영</font></li>
# <!--<li><img src="/images/bottom/bottom_icon01.gif" alt="" /> <a href="/search/direc_record.asp">기업 등록하기</a></li>-->
# </ul>
# <div id="address1">
# 	등록번호 : 서울 아00181 | 등록연월일 : 2006년 3월 17일 | 상호 : (주)더비엔 | 사업자등록번호 : 407-86-00506 | 대표 : 최정식   <img align="middle" alt="" height="20" id="inc" src="/images/new/inc.jpg"/><img align="middle" alt="" height="20" id="kina" src="/images/new/kina02.jpg"/><br/>
# 	주소 : 서울시 마포구 마포대로 25 (마포동, 신한디엠빌딩 13층) (우. 04167) | 전화 : 02-719-6933 | 팩스 : 02-715-8245 | E-mail : <a href="mailto:helpdesk@boannews.com">helpdesk@boannews.com</a>
# <p style="width:100%; padding:10px; background-color:#EFEFEF;"><b>「열린보도원칙」</b> <font color="#009AE8">당 매체는 독자와 취재원 등 뉴스이용자의 권리 보장을 위해 반론이나 정정보도, 추후보도를 요청할 수 있는 창구를 열어두고 있음을 알려드립니다.</font><br/>
# <b>고충처리인 권 준</b>(<a href="mailto:editor@boannews.com">editor@boannews.com</a>)</p>
# </div>
# <div id="address2">
# <span style="padding:20px;">Copyrightⓒ 2005 <a href="http://www.thebn.co.kr" target="_blank"><b>thebn Co., Ltd.</b></a> All rights reserved.</span>
# </div>
# </div>
# <div id="scroll_banner1" style="top:344px;left:50%;margin-left:-660px;width:100px;height:600px;position:absolute;z-index:200">
# <!--<a href="https://www.seconexpo.com" target="_blank"><img src="/images/banner/secon100_200.jpg"></a>
# <a href="https://www.egisec.org" target="_blank"><img src="/images/banner/egisec100_200.jpg" style="margin-top:5px;"></a>-->
# <iframe frameborder="0" height="605" id="main_side1" name="main_side1" src="/main_files/main_side1.asp" width="120"></iframe>
# </div>
# <div id="scroll_banner2" style="top:344px;left:50%;margin-left:560px;width:100px;height:600px;position:absolute;z-index:200">
# <!--<a href="http://weeds.co.kr/" target="_blank"><img src="/images/banner/weeds_ad.jpg"></a>-->
# <a href="https://www.boannews.com/premium" target="_blank"><img src="/images/banner/boannews_report.jpg"/></a>
# <a href="https://www.boannews.com/book/2021/buy.asp" target="_blank"><img src="/images/banner/ad_book.gif" style="margin-top:5px;"/></a>
# <iframe frameborder="0" height="605" id="main_side2" name="main_side2" src="/main_files/main_side2.asp" width="120"></iframe>
# </div>
# <!--
# 시큐리티월드 광고주 배너광고 리스트
# <div id="scroll_banner2" style="top:0px;left:50%;margin-left:560px;width:270px;position:absolute;background-color:#EFEFEF;border-radius:0px 0px 5px 5px;z-index:200;">
# <table width='270' border='0' cellspacing='0' cellpadding='0' style="margin:13px 0 3px 0;"><tr><td align='center'><a href='/securityworld/'><img src='/securityworld/img/sw_partner.png'></a></td></tr></table>
#
# 					<table border="0" cellpadding="0" cellspacing="0">
# 						<tr>
# 							<td width="90" align="center" style="font-size:11px;line-height:16px; letter-spacing:-2px;"><a href="/securityworld/ad_view.asp?idx="><img src="/pds/product/" width="80" height="35" border="0" style='border:1px solid #cccccc;'></a><br><b></b><br><font color="#999999"></font></td>
# 						</tr>
# 						<tr><td height="10"></td></tr>
# 					</table>
#
# <div>-->
# <!--팝업 설정 Start
# <div id="div_popup" style="position:absolute; z-index:200; top: 148px; left:50%; margin-left:-550px;width:500px; height:630px;">
# <TABLE cellSpacing=0 cellPadding=0 border="0" bgcolor="#000000">
# <form name="notice_form">
# 	<tr>
# 		<td><a href="https://www.boannews.com/book/2021/buy.asp" target="_blank" onFocus="this.blur();"><img src="/images/pop/market_report_pop.jpg" border="0"></a></td>
# 	</tr>
# 	<tr>
# 		<td height="30" align="right">
# 			<input type="checkbox" name="chkbox" value="checkbox" align="absmiddle">
# 			<font color="#ffffff" face="돋움" style="font-size:10pt">하루동안 이 창 띄우지 않음</font>&nbsp;&nbsp;<a href="javascript:closeWin();">
# 			<font color="#ffffff" face="돋움" style="font-size:10pt"><b>창닫기</b></font></a>&nbsp;&nbsp;&nbsp;</td>
# 	</tr>
# </form>
# </TABLE>
# </div>-->
# </body>
# </html>
