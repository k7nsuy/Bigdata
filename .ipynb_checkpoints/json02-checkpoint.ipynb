# %%
import requests
import json

url="https://raw.githubusercontent.com/IBM/taxinomitis/master/resources/datasets/numbers/titanic.json"
reponse = requests.get(url).text
# print(data, type(data))  # str

data = json.loads(reponse) 
# print(data["metadata"])

fields = []
for tmp in data["metadata"]["fields"]:
    fields.append(tmp['name'].replace(".",""))

fields.append('servived')
print(fields)

arr = []
for tmp in data["data"]["survived"]:
    tmp1 = { fields[0]:int(tmp[0]), 
             fields[1]:tmp[1],
             fields[2]:float(tmp[2]),
             fields[3]:int(tmp[3]),
             fields[4]:int(tmp[4]),
             fields[5]:float(tmp[5]),
             fields[6]:tmp[6],
             fields[7]:1 }
    arr.append(tmp1)

    
for tmp in data["data"]["did_not_survive"]:
    tmp1 = { fields[0]:int(tmp[0]), 
             fields[1]:tmp[1],
             fields[2]:float(tmp[2]),
             fields[3]:int(tmp[3]),
             fields[4]:int(tmp[4]),
             fields[5]:float(tmp[5]),
             fields[6]:tmp[6],
             fields[7]:0 }
    arr.append(tmp1)
arr
# Out:
# ['ticket class', 'gender', 'age', 'sibl sp', 'par ch', 'ticket fare', 'embarked', 'servived']
# [{'ticket class': 3,
#   'gender': 'male',
#   'age': 0.42,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 8.5167,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 0.75,
#   'sibl sp': 2,
#   'par ch': 1,
#   'ticket fare': 19.2583,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 0.75,
#   'sibl sp': 2,
#   'par ch': 1,
#   'ticket fare': 19.2583,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 1.0,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 15.7417,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 1.0,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 37.0042,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 3.0,
#   'sibl sp': 1,
#   'par ch': 2,
#   'ticket fare': 41.5792,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 4.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 13.4167,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 5.0,
#   'sibl sp': 2,
#   'par ch': 1,
#   'ticket fare': 19.2583,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 12.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 11.2417,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 13.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.2292,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 14.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 30.0708,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 14.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 11.2417,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 15.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 14.4542,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 15.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.225,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 16.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 57.9792,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 17.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 108.9,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 17.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 12.0,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 17.0,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 110.8833,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 18.0,
#   'sibl sp': 2,
#   'par ch': 2,
#   'ticket fare': 262.375,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 18.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 227.525,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 19.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 91.0792,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 20.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 15.7417,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 20.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.2292,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 21.0,
#   'sibl sp': 2,
#   'par ch': 2,
#   'ticket fare': 262.375,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 22.0,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 49.5,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 22.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.225,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 22.0,
#   'sibl sp': 1,
#   'par ch': 2,
#   'ticket fare': 41.5792,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 23.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 63.3583,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 23.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 113.275,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 23.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.7917,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 24.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 83.1583,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 24.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 69.3,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 24.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 69.3,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 24.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 49.5042,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 24.0,
#   'sibl sp': 0,
#   'par ch': 3,
#   'ticket fare': 19.2583,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 25.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 55.4417,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 25.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 91.0792,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 26.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 18.7875,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 26.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 30.0,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 27.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 76.7292,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 27.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 13.8583,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 28.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 24.0,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 29.0,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 15.2458,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 29.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.8958,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 30.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 56.9292,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 30.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 106.425,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 30.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 31.0,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 31.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 113.275,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 32.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 76.2917,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 32.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 30.5,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 35.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 512.3292,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 35.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.55,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 35.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 512.3292,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 36.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 135.6333,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 36.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 512.3292,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 38.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 71.2833,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 38.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 227.525,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 39.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 110.8833,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 39.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 83.1583,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 40.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 31.0,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 40.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 134.5,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 41.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 134.5,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 42.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 227.525,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 44.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 27.7208,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 44.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 57.9792,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 48.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 39.6,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 48.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 76.7292,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 49.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 76.7292,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 49.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 89.1042,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 49.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 56.9292,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 50.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 247.5208,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 52.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 78.2667,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 54.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 78.2667,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 54.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 59.4,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 56.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 35.5,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 56.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 83.1583,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 58.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 146.5208,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 60.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 75.25,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 60.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 79.2,
#   'embarked': 'Cherbourg',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 15.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 8.0292,
#   'embarked': 'Queenstwn',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 16.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.7333,
#   'embarked': 'Queenstwn',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 16.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.75,
#   'embarked': 'Queenstwn',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 19.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.8792,
#   'embarked': 'Queenstwn',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 22.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.75,
#   'embarked': 'Queenstwn',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 29.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.75,
#   'embarked': 'Queenstwn',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 30.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 12.35,
#   'embarked': 'Queenstwn',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 33.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 90.0,
#   'embarked': 'Queenstwn',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 0.67,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 14.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 0.83,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 29.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 0.83,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 18.75,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 0.92,
#   'sibl sp': 1,
#   'par ch': 2,
#   'ticket fare': 151.55,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 1.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 11.1333,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 1.0,
#   'sibl sp': 2,
#   'par ch': 1,
#   'ticket fare': 39.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 1.0,
#   'sibl sp': 1,
#   'par ch': 2,
#   'ticket fare': 20.575,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 2.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 2.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 12.2875,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 2.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 3.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 3.0,
#   'sibl sp': 4,
#   'par ch': 2,
#   'ticket fare': 31.3875,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 3.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 15.9,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 3.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 18.75,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 4.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 16.7,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 4.0,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 22.025,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 4.0,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 81.8583,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 4.0,
#   'sibl sp': 2,
#   'par ch': 1,
#   'ticket fare': 39.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 4.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 23.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 4.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 11.1333,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 5.0,
#   'sibl sp': 1,
#   'par ch': 2,
#   'ticket fare': 27.75,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 5.0,
#   'sibl sp': 4,
#   'par ch': 2,
#   'ticket fare': 31.3875,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 5.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 12.475,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 6.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 33.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 6.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 12.475,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 7.0,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 26.25,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 8.0,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 26.25,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 8.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 36.75,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 9.0,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 20.525,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 9.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 15.9,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 11.0,
#   'sibl sp': 1,
#   'par ch': 2,
#   'ticket fare': 120.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 13.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 19.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 14.0,
#   'sibl sp': 1,
#   'par ch': 2,
#   'ticket fare': 120.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 15.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 211.3375,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 16.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 8.05,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 16.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 86.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 16.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 39.4,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 17.0,
#   'sibl sp': 4,
#   'par ch': 2,
#   'ticket fare': 7.925,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 17.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 10.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 17.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 57.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 18.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 8.05,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 18.0,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 18.0,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 79.65,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 18.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 23.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 18.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 9.8417,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 18.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.4958,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 18.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 9.35,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 19.0,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 26.2833,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 19.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 7.8542,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 19.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 10.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 19.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 8.05,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 19.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 19.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 19.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 30.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 20.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 7.925,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 21.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 10.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 21.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.65,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 21.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.7958,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 21.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 77.9583,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 22.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.75,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 22.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 66.6,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 22.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 29.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 22.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 55.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 22.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.25,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 22.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.775,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 22.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 151.55,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 23.0,
#   'sibl sp': 3,
#   'par ch': 2,
#   'ticket fare': 263.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 23.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.55,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 24.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.1417,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 24.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 15.85,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 24.0,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 14.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 24.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 24.0,
#   'sibl sp': 3,
#   'par ch': 2,
#   'ticket fare': 263.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 24.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 24.0,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 16.7,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 24.0,
#   'sibl sp': 2,
#   'par ch': 3,
#   'ticket fare': 18.75,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 24.0,
#   'sibl sp': 2,
#   'par ch': 1,
#   'ticket fare': 27.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 24.0,
#   'sibl sp': 1,
#   'par ch': 2,
#   'ticket fare': 65.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 25.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 7.775,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 25.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 0.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 25.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 30.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 25.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 26.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.925,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 26.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 78.85,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 26.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.8542,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 26.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 56.4958,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 27.0,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 11.1333,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 27.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.7958,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 27.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.925,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 27.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 30.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 27.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 10.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 27.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 53.1,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 27.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 6.975,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 27.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 8.6625,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 27.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 12.475,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 28.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 35.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 28.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 12.65,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 28.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 28.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.55,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 28.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 28.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 29.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 29.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 10.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 29.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 9.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 29.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 29.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 211.3375,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 30.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 12.475,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 30.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 86.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 30.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 9.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 30.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 93.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 30.0,
#   'sibl sp': 3,
#   'par ch': 0,
#   'ticket fare': 21.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 30.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 31.0,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 164.8667,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 31.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 20.525,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 31.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 31.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 57.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 31.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.925,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 31.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 8.6833,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 31.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 26.25,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 32.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 56.4958,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 32.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 32.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 8.05,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 32.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 32.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.8542,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 32.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.925,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 32.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 56.4958,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 32.5,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 33.0,
#   'sibl sp': 3,
#   'par ch': 0,
#   'ticket fare': 15.85,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 33.0,
#   'sibl sp': 1,
#   'par ch': 2,
#   'ticket fare': 27.75,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 33.0,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 33.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 86.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 33.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 53.1,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 34.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 34.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 23.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 34.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 32.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 34.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.55,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 34.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 10.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 34.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 35.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 53.1,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 35.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 21.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 35.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 83.475,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 35.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 135.6333,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 35.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 20.25,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 35.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 52.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 35.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 90.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 35.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.2875,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 36.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 36.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 36.0,
#   'sibl sp': 1,
#   'par ch': 2,
#   'ticket fare': 120.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 36.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.2875,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 36.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 36.0,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 71.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 36.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 17.4,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 36.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.3875,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 36.0,
#   'sibl sp': 1,
#   'par ch': 2,
#   'ticket fare': 120.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 37.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 52.5542,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 38.0,
#   'sibl sp': 1,
#   'par ch': 5,
#   'ticket fare': 31.3875,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 38.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 90.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 39.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.925,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 39.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 79.65,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 39.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 55.9,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 40.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 15.75,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 40.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 40.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 153.4625,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 40.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 39.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 41.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 19.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 42.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 42.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 42.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 52.5542,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 42.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.2875,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 42.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 43.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 211.3375,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 44.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.925,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 45.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.55,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 45.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 8.05,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 45.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 26.25,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 45.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 45.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 164.8667,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 47.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 52.5542,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 48.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.55,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 48.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 52.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 48.0,
#   'sibl sp': 1,
#   'par ch': 2,
#   'ticket fare': 65.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 48.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 25.9292,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 49.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 25.9292,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 50.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 50.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 10.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 50.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 10.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 50.0,
#   'sibl sp': 2,
#   'par ch': 0,
#   'ticket fare': 133.65,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 51.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 77.9583,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 51.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.55,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 52.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 30.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 52.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 93.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 53.0,
#   'sibl sp': 2,
#   'par ch': 0,
#   'ticket fare': 51.4792,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 54.0,
#   'sibl sp': 1,
#   'par ch': 3,
#   'ticket fare': 23.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 55.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 16.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 58.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.55,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 58.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 153.4625,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 62.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 10.5,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'female',
#   'age': 63.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 77.9583,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 63.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 9.5875,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 80.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 30.0,
#   'embarked': 'Southampt',
#   'servived': 1},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 9.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 15.2458,
#   'embarked': 'Cherbourg',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 11.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 18.7875,
#   'embarked': 'Cherbourg',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 14.5,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 14.4542,
#   'embarked': 'Cherbourg',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 15.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 7.2292,
#   'embarked': 'Cherbourg',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 17.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 14.4583,
#   'embarked': 'Cherbourg',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 17.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 7.2292,
#   'embarked': 'Cherbourg',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 18.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 108.9,
#   'embarked': 'Cherbourg',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 18.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 14.4542,
#   'embarked': 'Cherbourg',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 20.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 4.0125,
#   'embarked': 'Cherbourg',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 22.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.2292,
#   'embarked': 'Cherbourg',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 22.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 135.6333,
#   'embarked': 'Cherbourg',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 23.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 15.0458,
#   'embarked': 'Cherbourg',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 23.5,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.2292,
#   'embarked': 'Cherbourg',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 24.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 247.5208,
#   'embarked': 'Cherbourg',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 24.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 79.2,
#   'embarked': 'Cherbourg',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 25.0,
#   'sibl sp': 1,
#   'par ch': 2,
#   'ticket fare': 41.5792,
#   'embarked': 'Cherbourg',
# ...
#   'par ch': 0,
#   'ticket fare': 15.55,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 36.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.4958,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 36.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 78.85,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 36.5,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 37.0,
#   'sibl sp': 2,
#   'par ch': 0,
#   'ticket fare': 7.925,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 37.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 53.1,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 37.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 9.5875,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 37.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 38.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.8958,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 38.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 153.4625,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 38.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 38.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.05,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 38.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 8.6625,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 38.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 0.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 39.0,
#   'sibl sp': 1,
#   'par ch': 5,
#   'ticket fare': 31.275,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 39.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.925,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 39.0,
#   'sibl sp': 1,
#   'par ch': 5,
#   'ticket fare': 31.275,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 39.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 39.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 39.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 0.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 39.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 39.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 24.15,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 40.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 9.475,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 40.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 0.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 40.0,
#   'sibl sp': 1,
#   'par ch': 4,
#   'ticket fare': 27.9,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 40.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.8958,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 40.5,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 14.5,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 41.0,
#   'sibl sp': 0,
#   'par ch': 2,
#   'ticket fare': 20.2125,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 41.0,
#   'sibl sp': 0,
#   'par ch': 5,
#   'ticket fare': 39.6875,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 41.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.125,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 41.0,
#   'sibl sp': 2,
#   'par ch': 0,
#   'ticket fare': 14.1083,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 42.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 52.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 42.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 42.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 8.4042,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 42.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 27.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 42.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 8.6625,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 42.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.65,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 42.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.55,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 43.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 26.25,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 43.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 8.05,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 43.0,
#   'sibl sp': 1,
#   'par ch': 6,
#   'ticket fare': 46.9,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 43.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 6.45,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 44.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 16.1,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 44.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 44.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 8.05,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 44.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 8.05,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 44.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 45.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 83.475,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 45.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 6.975,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 45.0,
#   'sibl sp': 1,
#   'par ch': 4,
#   'ticket fare': 27.9,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 45.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.75,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 45.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 35.5,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 45.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.55,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 45.5,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 28.5,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 46.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 61.175,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 46.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 47.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 52.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 47.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 14.5,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 47.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 38.5,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 47.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 34.0208,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 47.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 15.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 47.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.25,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 47.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 25.5875,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 47.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 9.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 48.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'female',
#   'age': 48.0,
#   'sibl sp': 1,
#   'par ch': 3,
#   'ticket fare': 34.375,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 48.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.8542,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 49.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 0.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 50.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 55.9,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 50.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 8.05,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 50.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 51.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 12.525,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 51.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 8.05,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 51.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.75,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 51.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.0542,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 52.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 79.65,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 52.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.5,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 52.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 54.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 51.8625,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 54.0,
#   'sibl sp': 0,
#   'par ch': 1,
#   'ticket fare': 77.2875,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 54.0,
#   'sibl sp': 1,
#   'par ch': 0,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 54.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 14.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 54.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 55.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 30.5,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 55.5,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 8.05,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 56.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.55,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'female',
#   'age': 57.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 10.5,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 59.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.25,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 59.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 13.5,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 60.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 39.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 60.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.55,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 61.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 33.5,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 61.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 6.2375,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 61.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 32.3208,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 62.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.55,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 62.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.55,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 64.0,
#   'sibl sp': 1,
#   'par ch': 4,
#   'ticket fare': 263.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 64.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 65.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 26.55,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 66.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 10.5,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 2,
#   'gender': 'male',
#   'age': 70.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 10.5,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 1,
#   'gender': 'male',
#   'age': 70.0,
#   'sibl sp': 1,
#   'par ch': 1,
#   'ticket fare': 71.0,
#   'embarked': 'Southampt',
#   'servived': 0},
#  {'ticket class': 3,
#   'gender': 'male',
#   'age': 74.0,
#   'sibl sp': 0,
#   'par ch': 0,
#   'ticket fare': 7.775,
#   'embarked': 'Southampt',
#   'servived': 0}]

# %%
# csv파일 만들어 데이터 저장
import csv


# 저장위치 ,w ,r ,a ,utf-8 ,euc-kr
file = open('csv/titanic.csv','w',encoding='utf-8')
wr = csv.writer(file) 
wr.writerow(['ticket class','gender','age','sibl sp','par ch','ticket fare','embarked','servived']) # column명 추가
for i in arr:
    wr.writerow(i)
file.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-97e93616875f> in <module>
#       2 import csv
#       3
# ----> 4 arr1 = json.loads(arr)
#       5 # 저장위치 ,w ,r ,a ,utf-8 ,euc-kr
#       6 file = open('csv/titanic.csv','w',encoding='utf-8')
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     339     else:
#     340         if not isinstance(s, (bytes, bytearray)):
# --> 341             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     342                             f'not {s.__class__.__name__}')
#     343         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not list
