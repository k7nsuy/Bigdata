# %%
# 라이브러리 설치하기
! pip install hdfs

# %%
# 데이터 저장
import hdfs #1 
import json
# from hdfs import InsecureClient #2

# psspark 스파크 = 실시간 데이터분석이 가능함.

# 1. hdfs web으로 접속 (9870,9864,9000,9866)
client_hdfs = hdfs.InsecureClient('http://1.234.5.158:9870', user='hdfs') #1
# InsecureClient() #2

# 2. 수집한 자료 [{}] (리스트(딕셔너리))
data = [{'name':'가1','weight':1,'height':2},{'name':'가1','weight':1,'height':2}]


# 3. 삭제하기
# client_hdfs.delete('/id117/ex_20210524.json')

# 4. 저장하기
# with는 자원을 흭득하고 사용 후 반납하는 경우에 사용
with client_hdfs.write('/id117/ex_20210525.json', encoding = 'utf-8') as writer:
    json.dump(data,writer)
    
# 5. 확인 크롬에서 http://1.234.5.158:9870/explorer.html#/

# %%
# 데이터 가져오기
from hdfs import InsecureClient
import pandas as pd

client_hdfs = InsecureClient('http://1.234.5.158:9870', user='hdfs')

# 파일 목록 확인
print(client_hdfs.list('/id117')) 

with client_hdfs.read('/id117/ex_20210524.json', encoding='utf-8') as reader:
    df = pd.read_json(reader)
# df.loc[:,['name']] name만 출력
df
#     for tmp in reader:
#         print(tmp)

# %%
! pip install selenium

# %%
from selenium import webdriver
import bs4 # pip install bs4
import time
# from selenium.webdriver.chrome.options import Options

url = 'https://shoppinghow.kakao.com/top'

options = webdriver.ChromeOptions()
driver = webdriver.Chrome(executable_path='driver/chromedriver.exe', options = options)
driver.get(url) # 창이 열림

time.sleep(1)
response = driver.page_source
# driver.close() # 창이 닫힘

soup = bs4.BeautifulSoup(response,'html.parser')

# for tmp in soup.select('#topRecomKeywordWrap > div.cont_item > ul > li > .tit_rank'):
#     print(tmp.text)

# find   == select_one
# find_all  == select

# data = [{},{},{},{}.. 20개 ]
data2 = []
# arr = {}
for idx, tmp in enumerate(soup.select('#topRecomKeywordWrap > div.cont_item > ul > li > .tit_rank')):
    data2.append( {str(idx+1) : tmp.text.strip().replace('.','') } )
#     arr[str(idx)] = tmp.text.strip()

print(data2)
# 1~20까지 수집한후 hdfs에 저장 datalab_naver_20210525.json 로 저장
driver.close() #창이 닫힘

# rankList = []
# for i in range(11):
#     string = rankList[i].select('#topRecomKeywordWrap > div.cont_item > ul > li > .tit_rank')[0].text.strip()
#     a = []
#     for j in string:
#         if not j.isdigit():
#             a.append(j)
#     newString = ''.join(a)
    
#     data = {'rank':i+1,'search':newString}
#     rankList.append(data)
# data

# 1~20 까지 수집한 후 hdfs에 저장 datalab_naver_20210524.json로 저장
# Out:
# [{'1': '1  선풍기안전망'}, {'2': '2  벨트백'}, {'3': '3  철제선반'}, {'4': '4  아카시아꿀'}, {'5': '5  점퍼루'}, {'6': '6  냉장고바지'}, {'7': '7  골프화'}, {'8': '8  크릴오일'}, {'9': '9  햇감자'}, {'10': '10  스팀다리미'}]

# %%
# 데이터 저장
import hdfs #1 
import json
# from hdfs import InsecureClient #2

# psspark 스파크 = 실시간 데이터분석이 가능함.

# 1. hdfs web으로 접속 (9870,9864,9000,9866)
client_hdfs = hdfs.InsecureClient('http://1.234.5.158:9870', user='hdfs') #1
# InsecureClient() #2

# 2. 수집한 자료 [{}] (리스트(딕셔너리))

# 3. 삭제하기
# client_hdfs.delete('/id117/ex_20210524.json')

# 4. 저장하기
# with는 자원을 흭득하고 사용 후 반납하는 경우에 사용
with client_hdfs.write('/id117/ex_datalab_naver_20210525.json', encoding = 'utf-8') as writer:
    json.dump(data2,writer)
    
# 5. 확인 크롬에서 http://1.234.5.158:9870/explorer.html#/

# %%
# 데이터 가져오기
from hdfs import InsecureClient
import pandas as pd

client_hdfs = InsecureClient('http://1.234.5.158:9870', user='hdfs')

# 파일 목록 확인
print(client_hdfs.list('/id117')) 

with client_hdfs.read('/id117/ex_datalab_naver_20210525.json', encoding='utf-8') as reader:
    df = pd.read_json(reader)
# df.loc[:,['name']] name만 출력
df
#     for tmp in reader:
#         print(tmp)
# Out:
# ['ex_20210524.json', 'ex_20210525.json', 'ex_datalab_naver_20210524.json', 'ex_datalab_naver_20210525.json']
#            1        2         3          4        5          6        7   \
# 0  1 . 선풍기안전망      NaN       NaN        NaN      NaN        NaN      NaN
# 1         NaN  2 . 벨트백       NaN        NaN      NaN        NaN      NaN
# 2         NaN      NaN  3 . 철제선반        NaN      NaN        NaN      NaN
# 3         NaN      NaN       NaN  4 . 아카시아꿀      NaN        NaN      NaN
# 4         NaN      NaN       NaN        NaN  5 . 점퍼루        NaN      NaN
# 5         NaN      NaN       NaN        NaN      NaN  6 . 냉장고바지      NaN
# 6         NaN      NaN       NaN        NaN      NaN        NaN  7 . 골프화
# 7         NaN      NaN       NaN        NaN      NaN        NaN      NaN
# 8         NaN      NaN       NaN        NaN      NaN        NaN      NaN
# 9         NaN      NaN       NaN        NaN      NaN        NaN      NaN
#
#          8        9           10
# 0       NaN      NaN         NaN
# 1       NaN      NaN         NaN
# 2       NaN      NaN         NaN
# 3       NaN      NaN         NaN
# 4       NaN      NaN         NaN
# 5       NaN      NaN         NaN
# 6       NaN      NaN         NaN
# 7  8 . 크릴오일      NaN         NaN
# 8       NaN  9 . 햇감자         NaN
# 9       NaN      NaN  10 . 스팀다리미
