# %%
from selenium import webdriver
import bs4 # pip install bs4
import time
# from selenium.webdriver.chrome.options import Options

url = 'https://shoppinghow.kakao.com/top'

# 옵션 설정
options = webdriver.ChromeOptions()
options.add_argument("disable-gpu")   
options.add_argument("lang=ko_KR")    
options.add_argument('user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36')  # user-agent
# options.add_argument('headless') # 크롬창 표시 X

# 드라이버 로딩
driver = webdriver.Chrome(executable_path='driver/chromedriver.exe', options = options)

# 페이지 접속
driver.get(url)

# 로딩되는 시간 1초 기다림
time.sleep(1)

# 로딩된 html 가져오기
response = driver.page_source

# html을 bs4로 파싱하기
soup = bs4.BeautifulSoup(response,'html.parser')

for tmp in soup.select('div#topRecomKeywordWrap'):
    for tmp1 in tmp.select('li'):
        print(tmp1.select_one('strong > a').text)
        print(tmp1.select_one('.num_price').text + '원')
        print(tmp1.select_one('.tit_g').text)
        print('-' * 30)
        
for tmp2 in soup.select('#topRecomKeywordWrap > div.cont_item > ul > li > .tit_rank'):
    print(tmp2.text)
    
# 크롬 창 닫기
driver.close()

//*[@id="topRecomKeywordWrap"]/div[2]/ul/li[1]/a/img

# 1~20 까지 수집한 후 hdfs에 저장 datalab_naver_20210524.json로 저장

# %%
# 이미지 불러오기 및 저장
from selenium import webdriver
import bs4 # pip install bs4
import time
import urllib.request as REQ # 서버 요청
# from selenium.webdriver.chrome.options import Options

url = 'https://shoppinghow.kakao.com/top'

# 옵션 설정
options = webdriver.ChromeOptions()
options.add_argument("disable-gpu")   
options.add_argument("lang=ko_KR")    
options.add_argument('user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36')  # user-agent
# options.add_argument('headless') # 크롬창 표시 X

# 드라이버 로딩
driver = webdriver.Chrome(executable_path='driver/chromedriver.exe', options = options)

# 페이지 접속
driver.get(url)

# 로딩되는 시간 1초 기다림
time.sleep(1)

# 로딩된 html 가져오기
response = driver.page_source

# html을 bs4로 파싱하기
soup = bs4.BeautifulSoup(response,'html.parser')
    
# 'a1c'
# 'a2c'

# for i in range(1,2000,1):
#     'a' + str(i) + 'c'
    
for idx in range(1,11,1):
    img = driver.find_element_by_xpath('//*[@id="topRecomKeywordWrap"]/div[2]/ul/li['+ str(idx) +']/a/img')
    print(img.get_attribute('src')) # 이미지 가져오기
    
    # 서버 요청(이미지의 url 주소, 저장 할 파일명) - 이미지 저장하기
    REQ.urlretrieve(img.get_attribute('src'),f'image/image{idx}.jpg')
    print('-' * 135)
    
# 크롬 창 닫기
driver.close()

# 1~20 까지 수집한 후 hdfs에 저장 datalab_naver_20210524.json로 저장

# %%
# 이미지 불러오기 및 저장
from selenium import webdriver
import bs4 # pip install bs4
import time
import urllib.request as REQ # 서버 요청
from selenium.webdriver.common.keys import Keys
# from selenium.webdriver.chrome.options import Options

url = 'https://www.naver.com/'

# 옵션 설정
options = webdriver.ChromeOptions()
options.add_argument("disable-gpu")   
options.add_argument("lang=ko_KR")    
options.add_argument('user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36')  # user-agent
# options.add_argument('headless') # 크롬창 표시 X

# 드라이버 로딩
driver = webdriver.Chrome(executable_path='driver/chromedriver.exe', options = options)

# 페이지 접속
driver.get(url)

response = driver.page_source

# html을 bs4로 파싱하기
soup = bs4.BeautifulSoup(response,'html.parser')


driver.find_element_by_xpath('//*[@id="query"]').send_keys('사과')
driver.find_element_by_xpath('//*[@id="query"]').send_keys(Keys.ENTER)

driver.find_element_by_xpath('//*[@id="lnb"]/div[1]/div/ul/li[2]/a').click()

for idx in range(1,6,1):
    time.sleep(1)
    try:
        img = driver.find_element_by_xpath('//*[@id="main_pack"]/section/div/div[1]/div[1]/div['+ str(idx) +']/div/div[1]/a/img')
        print(img.get_attribute('src'))
        REQ.urlretrieve(img.get_attribute('src'),f'image/image2_{idx}.jpg')
        
        print('-' * 30)
        
    except Exception as e:
        print(e)

driver.close()
# //*[@id="main_pack"]/section/div/div[1]/div[1]/div[1]/div/div[1]/a/img
# //*[@id="main_pack"]/section/div/div[1]/div[1]/div[2]/div/div[1]/a/img
# //*[@id="main_pack"]/section/div/div[1]/div[1]/div[10]/div/div[1]/a/img
# 1~20 까지 수집한 후 hdfs에 저장 datalab_naver_20210524.json로 저장

# %%
# 이미지 불러오기 및 저장
from selenium import webdriver
import bs4 # pip install bs4
import time
import urllib.request as REQ # 서버 요청
from selenium.webdriver.common.keys import Keys
# from selenium.webdriver.chrome.options import Options

url = 'http://www.kyobobook.co.kr/index.laf?OV_REFFER=https://www.google.com/'

# 옵션 설정
options = webdriver.ChromeOptions()
options.add_argument("disable-gpu")   
options.add_argument("lang=ko_KR")    
options.add_argument('user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36')  # user-agent
# options.add_argument('headless') # 크롬창 표시 X

# 드라이버 로딩
driver = webdriver.Chrome(executable_path='driver/chromedriver.exe', options = options)

# 페이지 접속
driver.get(url)

response = driver.page_source

# html을 bs4로 파싱하기
soup = bs4.BeautifulSoup(response,'html.parser')

driver.find_element_by_xpath('//*[@id="searchKeyword"]').send_keys('파이썬')
driver.find_element_by_xpath('//*[@id="searchKeyword"]').send_keys(Keys.ENTER)

# driver.find_element_by_xpath('//*[@id="lnb"]/div[1]/div/ul/li[2]/a').click()

for idx in range(1,4,1):
    time.sleep(1)
    try:
        img = driver.find_element_by_xpath('//*[@id="search_list"]/tr['+str(idx)+']/td[1]/div[2]/a/img')
        print(img.get_attribute('src'))
        REQ.urlretrieve(img.get_attribute('src'),f'image/image3_{idx}.jpg')
        
        print('-' * 30)
        
    except Exception as e:
        print(e)

driver.close()
# //*[@id="search_list"]/tr[1]/td[1]/div[2]/a/img
# //*[@id="search_list"]/tr[2]/td[1]/div[2]/a/img
# //*[@id="search_list"]/tr[3]/td[1]/div[2]/a/img
# 1~20 까지 수집한 후 hdfs에 저장 datalab_naver_20210524.json로 저장

# %%
# 이미지 불러오기 및 저장
from selenium import webdriver
import bs4 # pip install bs4
import time
import urllib.request as REQ # 서버 요청
from selenium.webdriver.common.keys import Keys
# from selenium.webdriver.chrome.options import Options

url = 'http://ihongss.com/webboard'

# 옵션 설정
options = webdriver.ChromeOptions()
options.add_argument("disable-gpu")   
options.add_argument("lang=ko_KR")    
options.add_argument('user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36')  # user-agent
# options.add_argument('headless') # 크롬창 표시 X

# 드라이버 로딩
driver = webdriver.Chrome(executable_path='driver/chromedriver.exe', options = options)

# 페이지 접속
driver.get(url)
time.sleep(1)

"""
<input type='text' name='email' value='' />
<input type='text' name='pw' value='' />
<script>
    document.getElementsByName('email')[0].value = 'b20221223';
    document.getElementsByName('pw')[0].value = 'b20221223';
    alert("로그인 되었음")
</script>
"""

driver.execute_script('document.getElementsByName("email")[0].value = "b20201223"')
driver.execute_script('document.getElementsByName("pw")[0].value = "b20201223"')
time.sleep(1)
driver.find_element_by_xpath('//*[@id="form1"]/div[3]/input').click()

# 로그인 이후의 페이지 가져오기
response = driver.page_source

# html을 bs4로 파싱하기
soup = bs4.BeautifulSoup(response,'html.parser')
soup

# driver.execute_script('alert("로그인 되었음!!")')
# 1~20 까지 수집한 후 hdfs에 저장 datalab_naver_20210524.json로 저장
